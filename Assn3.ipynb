# %%
import os
import sys
import time
import random
import argparse
import numpy as np
import pandas as pd
import scipy.sparse as sp

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn

from tqdm import tqdm
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
print("Python 版本:", sys.version)
print("PyTorch 版本:", torch.__version__)

# %% [markdown]
# 输出：
# Python 版本: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# PyTorch 版本: 2.3.0a0+6ddf5cf85e.nv24.04

# %%
# !pip install torch torchvision torchaudio --upgrade

# %%
print("Python 版本:", sys.version)
print("PyTorch 版本:", torch.__version__)

# %% [markdown]
# ### 开始处理数据

# %%
ratings = pd.read_csv('ml-1m/ratings.dat', sep='::', header = None, names=["UserID", "MovieID", "Rating", "Timestamp"])
users = pd.read_csv('ml-1m/users.dat', sep='::', header = None, names=["UserID", "Gender", "Age", "Occupation", "Zip-code"])
movies = pd.read_csv('ml-1m/movies.dat', sep='::', header = None, names=["MovieID", "Title", "Genres"], encoding='latin1')

# %%
print("ratings:\n", ratings.head(3), "\nusers:\n", users.head(3), "\nmovies:\n", movies.head(3))

# %% [markdown]
# ### 下面的chunk是为了在创建稀疏矩阵的时候避免第0行第0列全部为0，浪费资源
# ### 把UserID和MoovieID的索引都变成从0开始
# ### 注意：只能运行一次

# %%
ratings["UserID"] = ratings["UserID"]-1
ratings["MovieID"] = ratings["MovieID"]-1
ratings.head(5), ratings.shape

# %% [markdown]
# ### 测试集是每个UserID中最新的一个交互，也就是Timestamp最大的

# %%
# 对每个 UserID 分组，并找到最大 Timestamp 所在的索引
idx_test = ratings.groupby('UserID')['Timestamp'].idxmax()

# 使用这些索引来获取对应的行
df_testing_ps = ratings.loc[idx_test]

df_testing_ps.head(3)

# %% [markdown]
# ### 把原始数据集ratings去掉测试集的数据，再分为训练集和验证集
# ### 验证集对于每个UserID，随机一个即可

# %%
# ratings去掉测试集剩下的数据
ratings_left = ratings.drop(idx_test)

# 验证集
df_validation_ps = ratings_left.groupby('UserID').apply(lambda x: x.sample(1))
df_validation_ps.index.get_level_values(1)

# %%
df_training_ps = ratings_left.drop(df_validation_ps.index.get_level_values(1))
df_training_ps.shape

# %% [markdown]
# ### 现在已经获得了训练，验证，测试集的正样本。只选取前两列UserID和MovieID

# %%
df_testing_ps = df_testing_ps.iloc[:, 0:2]
df_validation_ps = df_validation_ps.iloc[:, 0:2]
df_training_ps = df_training_ps.iloc[:, 0:2]

df_testing_ps, df_validation_ps, df_training_ps

# %% [markdown]
# ### 开始创建稀疏矩阵

# %%
list_training_ps = df_training_ps.values.tolist()
len(list_training_ps)

# %%
UserID_num = ratings["UserID"].max()
MovieID_num = ratings["MovieID"].max()
UserID_num, MovieID_num

# %%
# 创建稀疏矩阵
training_mat = sp.dok_matrix((UserID_num+1, MovieID_num+1), dtype=np.float32)
# 往稀疏矩阵中添加元素
for UserID,MovieID in list_training_ps:
    training_mat[UserID, MovieID] = 1.0

# %%
# print(type(training_mat.keys()), type(training_mat.values()))
# for UserID,MovieID in training_mat.keys():
#     print(UserID, MovieID)
#     break

# %% [markdown]
# ### 先要找出每个UserID对应的所有MovieID，并储存在字典中

# %%
# 找到给定data数据集下，每个UserID对应的所有MovieID
def obtain_dict_UserIDMovieID(data, dictionary):
    for index,row in tqdm(data.iterrows(), total=data.shape[0]):
        UserID = row[0]
        MovieID = row[1]
        if UserID not in dictionary.keys():
            dictionary[UserID] = []
            dictionary[UserID].append(MovieID)  
        else:
            dictionary[UserID].append(MovieID)
    return dictionary

# %%
# 初始化字典
dict_total_UserIDMovieID = {}

# 运行方法
dict_total_UserIDMovieID = obtain_dict_UserIDMovieID(ratings.iloc[:, 0:2], dict_total_UserIDMovieID)

# %%
# 查看下结果
len(dict_total_UserIDMovieID[0]), len(dict_total_UserIDMovieID[1])

# %% [markdown]
# ### 创建正样本的字典

# %%
dict_training = {}
dict_validation = {}
dict_testing = {}

dict_training_ps = obtain_dict_UserIDMovieID(df_training_ps, dict_training)
dict_validation_ps = obtain_dict_UserIDMovieID(df_validation_ps, dict_validation)
dict_testing_ps = obtain_dict_UserIDMovieID(df_testing_ps, dict_testing)

# %% [markdown]
# ### 开始创建负样本

# %% [markdown]
# ### 训练集每个UserID需要4*正样本数个（来自neural_collaborative_filtering）
# ### 验证集每个UserID需要4个
# ### 测试集每个UserID需要100个

# %%
# 使用 groupby 和 size 来统计每个 UserID 的出现次数
user_counts = df_training_ps.groupby('UserID').size().reset_index(name='counts')

count_list = [count for count in user_counts["counts"]]

count_list[0], count_list[1], count_list[2]

# %%
num_training_ng = count_list
num_validation_ng = 4
num_testing_ng = 100

# %% [markdown]
# ### **注意：**我们需要保证每次随机生成的MovieID既不在原始数据集中，又不在前面随机生成过的MovieID中

# %%
round(1.2)

# %%
# 生成该UserID下相应个数的MovieID
def MovieID_generation(UserID, magnification, dict_ng_sample, dict_UserIDMovieID_generated): # magnification是倍率
    for i in range(round(count_list[UserID] * magnification)): # 生成count_list[UserID] * magnification个MovieID
        random_MovieID = random.randint(0, MovieID_num)
        while random_MovieID in dict_total_UserIDMovieID[UserID] or random_MovieID in dict_UserIDMovieID_generated[UserID]:
            random_MovieID = random.randint(0,MovieID_num)
        dict_ng_sample[UserID].append(random_MovieID)
        dict_UserIDMovieID_generated[UserID].append(random_MovieID)

# %%
# 新建一个dict储存在调用方法时生成的每个UserID对应的MovieID
dict_UserIDMovieID_generated = {}
# 先要对每个UserID初始化一个list
for UserID in range(UserID_num+1):
    dict_UserIDMovieID_generated[UserID] = []

def ng_sample_generation_bylist(count_list):
    '''
    count_list是一个list，其中的每个元素代表对于该UserID，需要生成几个负样本
    '''
    
    dict_ng_sample = {} # 结构与dict_UserIDMovieID类似

    for UserID in tqdm(range(UserID_num+1)):
        dict_ng_sample[UserID] = []
                       
        # 如果该UserID对应的MovieID个数小于等于0.19*(MovieID_num + 1)，我们采取4倍的负样本率
        if count_list[UserID] <= 0.19 * (MovieID_num + 1): 
            MovieID_generation(UserID, 4, dict_ng_sample, dict_UserIDMovieID_generated)
        # 如果UserID对应的MovieID个数大于0.19*(MovieID_num + 1)，小于0.49*(MovieID_num + 1)，我们采取1倍的负样本率
        elif 0.19 * (MovieID_num + 1) < count_list[UserID] <= 0.49 * (MovieID_num + 1):
            MovieID_generation(UserID, 1, dict_ng_sample, dict_UserIDMovieID_generated)              
        # 如果UserID对应的MovieID个数大于0.49*(MovieID_num + 1)，小于0.66*(MovieID_num + 1)，我们采取0.5倍的负样本率
        elif 0.49 * (MovieID_num + 1) < count_list[UserID] < 0.66 * (MovieID_num + 1):
            MovieID_generation(UserID, 0.5, dict_ng_sample, dict_UserIDMovieID_generated)
        else:
            print(UserID)
                
    return dict_ng_sample

# %%
def ng_sample_generation_bynum(count):
    '''
    count代表一个UserID要生成几个MovieID
    '''
    
    dict_ng_sample = {} # 结构与dict_UserIDMovieID类似

    for UserID in tqdm(range(UserID_num+1)):
        dict_ng_sample[UserID] = []
        for i in range(count): # 生成count_list[UserID] * magnification个MovieID
            random_MovieID = random.randint(0, MovieID_num)
            while random_MovieID in dict_total_UserIDMovieID[UserID] or random_MovieID in dict_UserIDMovieID_generated[UserID]:
                random_MovieID = random.randint(0,MovieID_num)
            dict_ng_sample[UserID].append(random_MovieID)
            dict_UserIDMovieID_generated[UserID].append(random_MovieID)
                
    return dict_ng_sample

# %% [markdown]
# ### 生成用于训练，验证和测试的负样本字典

# %%
dict_training_ng = ng_sample_generation_bylist(num_training_ng)
dict_validation_ng = ng_sample_generation_bynum(num_validation_ng)
dict_testing_ng = ng_sample_generation_bynum(num_testing_ng)

# %%
dict_training_ng[1], dict_validation_ng[0], dict_testing_ng[0]

# %%
for i in tqdm(range(UserID_num+1)):
    print(count_list[i], len(dict_training_ng[i]), len(dict_validation_ng[i]), len(dict_testing_ng[i]))
    break

# %% [markdown]
# ### 开始合并正样本和负样本
# 现在有：
# dict_training_ps, dict_validation_ps, dict_testing_ps
# dict_training_ng, dict_validation_ng, dict_testing_ng

# %%
def dict_conbine_ps_ng(dict_ps, dict_ng):
    dict_total = {}
    labels_total = []
    for UserID in tqdm(range(UserID_num+1)): 
        
        dict_total[UserID] = dict_ps[UserID] + dict_ng[UserID]
        
        len_label_ps = len(dict_ps[UserID])
        len_label_ng = len(dict_ng[UserID])
        
        labels_ps = [1 for _ in range(len_label_ps)]
        labels_ng = [0 for _ in range(len_label_ng)]
        
        labels_total = labels_total + labels_ps + labels_ng
    return dict_total, labels_total

# %%
dict_training_all, labels_training_all = dict_conbine_ps_ng(dict_training_ps, dict_training_ng)
dict_validation_all, labels_validation_all = dict_conbine_ps_ng(dict_validation_ps, dict_validation_ng)
dict_testing_all, labels_testing_all = dict_conbine_ps_ng(dict_testing_ps, dict_testing_ng)

# %%
# len(dict_training_all[0]), labels_training_all[0:256]

# %% [markdown]
# ### 将字典转化为二维list

# %%
# 转换为二维列表
list_training_all = [[key, value] for key, values in dict_training_all.items() for value in values]
list_validation_all = [[key, value] for key, values in dict_validation_all.items() for value in values]
list_testing_all = [[key, value] for key, values in dict_testing_all.items() for value in values]

# %%
len(list_training_all), list_training_all[0:5]

# %% [markdown]
# ### 现在有训练集全部数据list_training_all, 训练集全部标签labels_training_all

# %% [markdown]
# ### 使用d2l的load_array()，但没有shuffle

# %%
# def load_array(data_arrays, batch_size, is_train=True):  
#     dataset = data.TensorDataset(*data_arrays)
#     return data.DataLoader(dataset, batch_size, shuffle=is_train)

# %%
# train_features = torch.tensor(list_training_all, dtype=torch.float32)
# train_labels = torch.tensor(labels_training_all, dtype=torch.float32)

# %%
# batch_size = 16
# train_loader = load_array((train_features, train_labels), batch_size)

# %%
# for a,b in train_loader:
#     print(a, b)
#     break

# %% [markdown]
# ### 使用DataLoader，有shuffle

# %% [markdown]
# ### 将二维list和一维的list转化成可以使用Pytorch训练的格式

# %%
class CustomDataset(Dataset):
    def __init__(self, features, labels):
        self.features = features
        self.labels = labels
    
    def __len__(self):
        return len(self.features)
    
    def __getitem__(self, idx):
        return torch.tensor(self.features[idx], dtype=torch.float), torch.tensor(self.labels[idx], dtype=torch.long)

# %%
# 假设 train_features 和 test_features 是你的二维列表数据
# train_labels 和 test_labels 是对应的标签列表
train_dataset = CustomDataset(list_training_all, labels_training_all)
validation_dataset = CustomDataset(list_validation_all, labels_validation_all)
test_dataset = CustomDataset(list_testing_all, labels_testing_all)

# %% [markdown]
# ### 数据处理完成

# %%
batch_size_list = [128, 256, 512, 1024]

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4)
validation_loader = DataLoader(validation_dataset, batch_size=64, shuffle=True, num_workers=1)
test_loader = DataLoader(test_dataset, batch_size=101, shuffle=True, num_workers=1)

# %% [markdown]
# # 我们选择在初始化模型时定义优化器和损失函数，而不是在训练过程中指定

# %% [markdown]
# # GMF

# %%
class GMF(nn.Module):
    def __init__(self, user_num, item_num, embedding_dim):
        super(GMF, self).__init__()
        """
        user_num: number of users;
        item_num: number of items;
        embedding_dim: number of embedding dimensions;
        hidden_layer: dimension of each hidden layer (list type)
        """

        self.embed_user = nn.Embedding(user_num, embedding_dim)
        self.embed_item = nn.Embedding(item_num, embedding_dim)
        
        self.predict_layer = nn.Linear(embedding_dim, 1)

        nn.init.normal_(self.embed_user.weight, std=0.01)
        nn.init.normal_(self.embed_item.weight, std=0.01)

        nn.init.kaiming_uniform_(self.predict_layer.weight, a=1, nonlinearity='sigmoid')

        # Kaiming/Xavier initialization can not deal with non-zero bias terms
        if self.predict_layer.bias is not None:
            self.predict_layer.bias.data.zero_()

    def forward(self, user, item):
        embed_user = self.embed_user(user)
        embed_item = self.embed_item(item)
        
        output = embed_user * embed_item
        prediction = self.predict_layer(output)
        return prediction.view(-1)

# %%
embedding_dim = 8
GMF_model = GMF(UserID_num+1, MovieID_num+1, embedding_dim)

# 定义优化器
lr = 0.0001
optimizer = optim.Adam(GMF_model.parameters(), lr=lr)

# 定义损失函数
loss_function = nn.BCEWithLogitsLoss()

# %%
training_model(GMF_model, train_loader, test_loader, 10, 10)

# %% [markdown]
# # MLP

# %%
import torch
import torch.nn as nn

class MLP(nn.Module):
    def __init__(self, user_num, item_num, layers, reg_layers, dropout):
        super(MLP, self).__init__()
        '''
        layers: List containing the output size of each layer, e.g., [64, 32, 16, 8]
        reg_layers: List containing the L2 regularization strength for each layer
        '''

        # Ensure input lists have correct dimensions
        assert len(layers) == len(reg_layers) & len(layers) == len(dropout), "Lengths of layers and reg_layers must be equal"

        # Embedding dimensions should be half of the first layer size
        embedding_dim = layers[0] // 2

        self.embed_user = nn.Embedding(user_num, embedding_dim)
        self.embed_item = nn.Embedding(item_num, embedding_dim)
        
        # Initializing the MLP layers
        self.layers = nn.ModuleList()
        input_dim = embedding_dim * 2  # User and item embeddings are concatenated

        for idx, (layer_size, dropout_rate) in enumerate(zip(layers, reg_layers)):
            layer = nn.Linear(input_dim, layer_size)
            # Applying L2 Regularization by adding weight decay directly into the optimizer setup later
            self.layers.append(layer)
            self.layers.append(nn.ReLU())
            if dropout_rate > 0:
                self.layers.append(nn.Dropout(dropout_rate))
            input_dim = layer_size
            
        # 添加最后一个输出层，确保输出尺寸为1
        self.layers.append(nn.Linear(layers[-1], 1))

    def forward(self, user, item):
        embed_user = self.embed_user(user)  # shape: (batch_size, embedding_dim)
        embed_item = self.embed_item(item)  # shape: (batch_size, embedding_dim)
        
        # Concatenate user and item embeddings to form input to MLP layers
        vector = torch.cat([embed_user, embed_item], dim=1)  # shape: (batch_size, 2*embedding_dim)

        # 通过 MLP 层
        for layer in self.layers:
            vector = layer(vector)
            
        return vector.reshape(-1)

# %%
layers_test = []
n = 1 # n为layers的个数。已经测试了 ，正在测试4
factors = 8 # factors为最后一个隐藏层的大小。已经测试了8，正在测试16
for i in range(n):
    layers_test = [factors] + layers_test
    factors = 2*factors
layers = layers_test

reg_layers = [0]
droupout = [0]

MLP_model = MLP(UserID_num+1, MovieID_num+1, layers, reg_layers, droupout)

# 收集不同层的参数，并为每一层应用不同的权重衰减
param_groups = [
    {'params': MLP_model.embed_user.parameters(), 'weight_decay': reg_layers[0]},
    {'params': MLP_model.embed_item.parameters(), 'weight_decay': reg_layers[0]}
]

# 为MLP每一层添加对应的权重衰减
for i, layer in enumerate(MLP_model.layers):
    if isinstance(layer, nn.Linear) and i < 2*len(layers): # 应该有4*2+1层隐藏层
        layer_idx = i // 2  # 因为每一个Linear层后面都跟着一个ReLU层
        param_groups.append({'params': layer.parameters(), 'weight_decay': reg_layers[layer_idx]})

# 使用带有不同权重衰减的参数组创建优化器
lr = 0.0001
optimizer = torch.optim.Adam(param_groups, lr=lr)

# 定义损失函数
loss_function = nn.BCEWithLogitsLoss()

# %%
layers

# %%
training_model(MLP_model, train_loader, test_loader, 10, 10)

# %% [markdown]
# # NeuMF

# %%
embedding_dim = 8
GMF_model = GMF(UserID_num+1, MovieID_num+1, embedding_dim)
layers = [128, 64, 32, 8]
reg_layers = [0, 0, 0, 0]
droupout = [0, 0, 0, 0]
MLP_model = MLP(UserID_num+1, MovieID_num+1, layers, reg_layers, droupout)

# 定义损失函数
loss_function = nn.BCEWithLogitsLoss()

# 定义GMF_model的优化器
lr = 0.001
optimizer = optim.Adam(GMF_model.parameters(), lr=lr)
print("开始训练GMF_model\n")
training_model(GMF_model, train_loader, test_loader, 10, 10)

# 定义MLP_model的优化器
lr = 0.001
optimizer = optim.Adam(MLP_model.parameters(), lr=lr)
print("开始训练MLP_model\n")
training_model(MLP_model, train_loader, test_loader, 10, 10)

# %%
class NeuMF(nn.Module):
    def __init__(self, user_num, item_num, gmf_embedding_dim, mlp_layers, reg_layers, dropout, alpha=0.5):
        super(NeuMF, self).__init__()
        '''
        user_num: number of users
        item_num: number of items
        gmf_embedding_dim: embedding size for GMF part
        mlp_layers: List containing the output size of each layer in MLP, e.g., [64, 32, 16, 8]
        reg_layers: List containing the L2 regularization strength for each layer in MLP
        dropout: List containing dropout rate for each layer in MLP
        alpha: hyper-parameter determining the trade-off between GMF and MLP
        '''

        self.alpha = alpha

        # GMF part
        self.embed_user_GMF = nn.Embedding(user_num, gmf_embedding_dim)
        self.embed_item_GMF = nn.Embedding(item_num, gmf_embedding_dim)
        
        nn.init.normal_(self.embed_user_GMF.weight, std=0.01)
        nn.init.normal_(self.embed_item_GMF.weight, std=0.01)

        # MLP part
        embedding_dim = mlp_layers[0] // 2
        self.embed_user_MLP = nn.Embedding(user_num, embedding_dim)
        self.embed_item_MLP = nn.Embedding(item_num, embedding_dim)
        
        nn.init.normal_(self.embed_user_MLP.weight, std=0.01)
        nn.init.normal_(self.embed_item_MLP.weight, std=0.01)
        
        # MLP layers
        self.mlp_layers = nn.ModuleList()
        input_dim = embedding_dim * 2

        for layer_size, dropout_rate in zip(mlp_layers, dropout):
            self.mlp_layers.append(nn.Linear(input_dim, layer_size))
            self.mlp_layers.append(nn.ReLU())
            if dropout_rate > 0:
                self.mlp_layers.append(nn.Dropout(dropout_rate))
            input_dim = layer_size
        
        # Final prediction layer
        predict_size = gmf_embedding_dim + mlp_layers[-1]
        self.predict_layer = nn.Linear(predict_size, 1)
        nn.init.kaiming_uniform_(self.predict_layer.weight, a=1, nonlinearity='sigmoid')
        
        if self.predict_layer.bias is not None:
            self.predict_layer.bias.data.zero_()

    def forward(self, user, item):
        # GMF part
        embed_user_GMF = self.embed_user_GMF(user)
        embed_item_GMF = self.embed_item_GMF(item)
        gmf_output = embed_user_GMF * embed_item_GMF # 输出大小：batch_size * gmf_embedding_dim

        # MLP part
        embed_user_MLP = self.embed_user_MLP(user)
        embed_item_MLP = self.embed_item_MLP(item)
        mlp_vector = torch.cat([embed_user_MLP, embed_item_MLP], dim=1)
        
        for layer in self.mlp_layers:
            mlp_vector = layer(mlp_vector) # 输出大小：batch_size * 最后一个隐藏层的size

        # Concatenate GMF and MLP parts
        final_vector = torch.cat([self.alpha * gmf_output, (1 - self.alpha) * mlp_vector], dim=1)
 # 输出大小：batch_size * (gmf_embedding_dim + 最后一个隐藏层的size)

        # Final prediction
        prediction = self.predict_layer(final_vector)
        return prediction.view(-1)
    
    def load_pretrained_weights(self, gmf_model, mlp_model):
        self.embed_user_GMF.weight.data.copy_(gmf_model.embed_user.weight)
        self.embed_item_GMF.weight.data.copy_(gmf_model.embed_item.weight)
        
        self.embed_user_MLP.weight.data.copy_(mlp_model.embed_user.weight)
        self.embed_item_MLP.weight.data.copy_(mlp_model.embed_item.weight)
        
        for (self_layer, gmf_layer), (_, mlp_layer) in zip(self.mlp_layers.named_children(), mlp_model.layers.named_children()):
            if isinstance(self_layer, nn.Linear):
                self_layer.weight.data.copy_(mlp_layer.weight)
                if self_layer.bias is not None:
                    self_layer.bias.data.copy_(mlp_layer.bias)

# %%
gmf_embedding_dim = embedding_dim
mlp_layers = layers
reg_layers = reg_layers
dropout = droupout
# 创建NeuMF模型并加载预训练参数
NeuMF_model = NeuMF(UserID_num+1, MovieID_num+1, gmf_embedding_dim, mlp_layers, reg_layers, dropout, alpha=0.5)
NeuMF_model.load_pretrained_weights(GMF_model, MLP_model)

# 使用SGD优化器训练NeuMF
lr = 0.001
optimizer = optim.SGD(NeuMF_model.parameters(), lr=lr)
loss_function = nn.BCEWithLogitsLoss()

# %%
training_model(NeuMF_model, train_loader, test_loader, 10, 10)

# %% [markdown]
# # evaluate

# %%
def evaluate(model, test_loader, top_k):
    hits = 0
    NDCG = 0
    correct = 0 # 测试集上正确预测的个数
    total = 0 # 总共的样本数

    for user_item, label in test_loader:
        user = user_item[:, 0]
        item = user_item[:, 1]

        user = user.long().to(device)
        item = item.long().to(device)
        label = label.float().to(device)  # 确保标签也在同一设备
        
        predictions = model(user, item)
        _, indices = torch.topk(predictions, top_k) # 得到predictions中前top_k大的值的索引
        # 由于我们没有shuffle，且一个batch 101个，正好是一个正样本+一百个负样本
        indices = indices.tolist()
        # 计算HR
        if 0 in indices:
            hits += 1
        # 计算NDCG
        position = [i for i, x in enumerate(indices) if x == 0] # [i for i, x in enumerate(indices) if x == 0]为只包含一个元素的list
        if len(position) == 0:
            NDCG += 0
        else:
            position = position[0]
            NDCG += 1/np.log2(position+1+1)
            
        # 计算测试集上的准确率
        # 应用 Sigmoid 函数以将输出转换为概率
        probabilities = torch.sigmoid(predictions)
        # 将概率转换为二进制预测
        predicted_labels = (probabilities > 0.5).float()  # 使用0.5作为阈值
        correct += (predicted_labels == label).sum().item()
        total += label.size(0)
    
    accuracy = 100 * correct / total
    print(f"测试集上的准确率为：{accuracy:.2f}%")
    
    # 根据公式计算HR
    HR = hits/len(test_loader)
    # 根据公式计算NDCG
    NDCG = NDCG/len(test_loader)
    
    return HR,NDCG

# %% [markdown]
# # 训练过程

# %%
# 检查是否存在 GPU，否则使用 CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def training_model(model, train_loader, test_loader, epochs, top_k, batch_size, lr, factor):

    # 使用GPU加速
    model.to(device)
    # 记录所有epoch中最好的HR和NDCG
    best_HR = 0
    best_NDCG = 0
    
    ########################### TRAINING #####################################
    for epoch in range(epochs):
        loss_everyepoch = 0 # 训练中每个eopch的loss
        correct = 0
        total = 0
        # 训练模式
        model.train() 
        # 添加一个计时器
        start_time = time.time()
        for user_item, label in train_loader:
            user = user_item[:, 0]
            item = user_item[:, 1]
            
            # print(user.shape, type(user))
            user = user.long().to(device)
            item = item.long().to(device)
            label = label.float().to(device)
            
            model.zero_grad()
            prediction = model(user, item)
            
            # 应用 Sigmoid 函数以将输出转换为概率
            probabilities = torch.sigmoid(prediction)
            # 将概率转换为二进制预测
            predicted_labels = (probabilities > 0.5).float()  # 使用0.5作为阈值

            # 计算准确率
            # print(predicted_labels.shape, label.shape, predicted_labels)
            correct += (predicted_labels == label).sum().item()
            # print(correct)
            total += label.size(0)
    
            loss = loss_function(prediction, label)
            loss_everyepoch += loss
            loss.backward()
            optimizer.step()
            
        accuracy = 100 * correct / total
        print(f"Epoch {epoch + 1}/{epochs}, Accuracy: {accuracy:.2f}%, Loss in this epoch: {loss_everyepoch}")
        
        # 测试模式
        model.eval()
        HR, NDCG = evaluate(model, test_loader, top_k)
        
        if HR > best_HR:
            best_HR = HR
        if NDCG > best_NDCG:
            best_NDCG = NDCG
        
        elapsed_time = time.time() - start_time
#         print("The time elapse of epoch {:03d}".format(epoch) + " is: " +
#                 time.strftime("%H: %M: %S", time.gmtime(elapsed_time)))
        print("HR: {:.3f}\tNDCG: {:.3f}".format(np.mean(HR), np.mean(NDCG)))
    
    print("本次训练最高的HR为：", best_HR, "最高的NDCG为：", best_NDCG)
    # 获取模型名称
    model_name = type(model).__name__
    if model_name == "GMF":
        append_to_csv(GMF_csv_filename, batch_size, lr, factor, best_HR, best_NDCG)
    elif model_name == "MLP":
        if epochs > 5:
            append_to_csv(MLP_filename, batch_size, lr, factor, best_HR, best_NDCG)
        else:
            append_to_csv(MLP_csv_filename, batch_size, lr, factor, best_HR, best_NDCG)
    elif model_name == "NeuMF":
        append_to_csv(NeuMF_csv_filename, batch_size, lr, factor, best_HR, best_NDCG)

# %%
MLP_filename = "outcome/MLP_n.csv"

with open(MLP_filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    # 写入表头
    writer.writerow(['batch_size', 'lr', 'factor', "HR", "NDCG"])

# %% [markdown]
# ### GMF上，0.001的学习率，训练集上的acc快速上升并达到稳定
# ### MLP上，0.001的学习率也是快速收敛

# %% [markdown]
# # (1)第一问

# %% [markdown]
# ### 将训练结果保存

# %%
import csv

# 定义CSV文件的文件名
GMF_csv_filename = 'outcome/GMF.csv'
MLP_csv_filename = 'outcome/MLP.csv'
NeuMF_csv_filename = 'outcome/NeuMF.csv'

csv_filename_list = [GMF_csv_filename, MLP_csv_filename, NeuMF_csv_filename]

# 创建并初始化CSV文件，写入表头
for csv_filename in csv_filename_list:
    with open(csv_filename, mode='w', newline='') as file:
        writer = csv.writer(file)
        # 写入表头
        writer.writerow(['batch_size', 'lr', 'factor', "HR", "NDCG"])

# 函数：逐行添加数据到CSV文件
def append_to_csv(csv_filename, batch_size, lr, factor, HR, NDCG):
    with open(csv_filename, mode='a', newline='') as file:
        writer = csv.writer(file)
        # 写入一行数据
        writer.writerow([batch_size, lr, factor, HR, NDCG])

# 示例：逐行添加数据
# append_to_csv(GMF_csv_filename, 1, 11, 1, 101, 5)

# print(f"数据已成功添加到 {csv_filename} 文件中。")

# %% [markdown]
# ### 同时训练三个模型

# %%
batch_size_list = [128, 256, 512, 1024]
lr_list = [0.0001 ,0.0005, 0.001, 0.005]
factors = [8, 16, 32, 64]

# %%
for batch_size in batch_size_list:
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4)
    validation_loader = DataLoader(validation_dataset, batch_size=64, shuffle=True, num_workers=1)
    test_loader = DataLoader(test_dataset, batch_size=101, shuffle=False, num_workers=1)
    
    for lr in lr_list:
        for factor in factors:
    
            embedding_dim = factor
            lr = lr
            loss_function = nn.BCEWithLogitsLoss() # 定义损失函数
        
            GMF_model = GMF(UserID_num+1, MovieID_num+1, embedding_dim)
        
            layers =  [factor*(2**i) for i in reversed(range(4))] # range里面的数代表几层隐藏层，4代表3层
            reg_layers = [0] * 4
            droupout = [0] * 4
            MLP_model = MLP(UserID_num+1, MovieID_num+1, layers, reg_layers, droupout)
        
            print("本次训练batch_size为：", batch_size, "lr为：", lr, "factor为：", factor, "开始训练GMF_model")
            optimizer = optim.Adam(GMF_model.parameters(), lr=lr) # 定义优化器
            training_model(GMF_model, train_loader, test_loader, 5, 10, batch_size, lr, factor) 
            
            print("本次训练batch_size为：", batch_size, "lr为：", lr, "factor为：", factor, "开始训练MLP_model")
            optimizer = optim.Adam(MLP_model.parameters(), lr=lr) # 定义优化器
            training_model(MLP_model, train_loader, test_loader, 5, 10, batch_size, lr, factor) 
        
            ############################## NeuMF_model ####################################
            gmf_embedding_dim = factor
            mlp_layers = layers
            reg_layers = reg_layers
            dropout = droupout
            # 创建NeuMF模型并加载预训练参数
            NeuMF_model = NeuMF(UserID_num+1, MovieID_num+1, gmf_embedding_dim, mlp_layers, reg_layers, dropout, alpha=0.5)
            NeuMF_model.load_pretrained_weights(GMF_model, MLP_model)
            # 使用SGD优化器训练NeuMF
            lr = lr
            optimizer = optim.SGD(NeuMF_model.parameters(), lr=lr)
            loss_function = nn.BCEWithLogitsLoss()
        
            print("本次训练batch_size为：", batch_size, "lr为：", lr, "factor为：", factor, "开始训练NeuMF_model")
            training_model(NeuMF_model, train_loader, test_loader, 5, 10, batch_size, lr, factor)
# Out:
# 本次训练batch_size为： 128 lr为： 0.0001 factor为： 8 开始训练GMF_model
# Epoch 1/5, Accuracy: 79.94%, Loss in this epoch: 16611.248046875
# 测试集上的准确率为：95.19%
# HR: 0.457	NDCG: 0.257
# Epoch 2/5, Accuracy: 82.77%, Loss in this epoch: 12996.66015625
# 测试集上的准确率为：93.34%
# HR: 0.462	NDCG: 0.259
# Epoch 3/5, Accuracy: 82.73%, Loss in this epoch: 12860.7421875
# 测试集上的准确率为：92.56%
# HR: 0.464	NDCG: 0.260
# Epoch 4/5, Accuracy: 82.65%, Loss in this epoch: 12776.8935546875
# 测试集上的准确率为：92.23%
# HR: 0.463	NDCG: 0.260
# Epoch 5/5, Accuracy: 82.74%, Loss in this epoch: 12646.30859375
# 测试集上的准确率为：91.95%
# HR: 0.465	NDCG: 0.262
# 本次训练最高的HR为： 0.4649006622516556 最高的NDCG为： 0.2617680124619066
# 本次训练batch_size为： 128 lr为： 0.0001 factor为： 8 开始训练MLP_model
# Epoch 1/5, Accuracy: 80.97%, Loss in this epoch: 15200.6533203125
# 测试集上的准确率为：92.12%
# HR: 0.454	NDCG: 0.255
# Epoch 2/5, Accuracy: 83.07%, Loss in this epoch: 12949.5908203125
# 测试集上的准确率为：91.46%
# HR: 0.462	NDCG: 0.258
# Epoch 3/5, Accuracy: 83.45%, Loss in this epoch: 12657.41796875
# 测试集上的准确率为：92.79%
# HR: 0.463	NDCG: 0.257
# Epoch 4/5, Accuracy: 83.60%, Loss in this epoch: 12554.1796875
# 测试集上的准确率为：92.77%
# HR: 0.465	NDCG: 0.259
# Epoch 5/5, Accuracy: 83.67%, Loss in this epoch: 12502.7939453125
# 测试集上的准确率为：93.06%
# HR: 0.461	NDCG: 0.259
# 本次训练最高的HR为： 0.4645695364238411 最高的NDCG为： 0.25884657040869
# 本次训练batch_size为： 128 lr为： 0.0001 factor为： 8 开始训练NeuMF_model
# Epoch 1/5, Accuracy: 77.76%, Loss in this epoch: 20914.96875
# 测试集上的准确率为：99.01%
# HR: 0.462	NDCG: 0.257
# Epoch 2/5, Accuracy: 78.22%, Loss in this epoch: 18379.78125
# 测试集上的准确率为：99.01%
# HR: 0.462	NDCG: 0.259
# Epoch 3/5, Accuracy: 78.22%, Loss in this epoch: 17779.474609375
# 测试集上的准确率为：99.01%
# HR: 0.463	NDCG: 0.260
# Epoch 4/5, Accuracy: 78.22%, Loss in this epoch: 17532.599609375
# 测试集上的准确率为：99.01%
# HR: 0.464	NDCG: 0.261
# Epoch 5/5, Accuracy: 78.22%, Loss in this epoch: 17373.109375
# 测试集上的准确率为：99.01%
# HR: 0.465	NDCG: 0.261
# 本次训练最高的HR为： 0.4653973509933775 最高的NDCG为： 0.26118682446065655
# 本次训练batch_size为： 128 lr为： 0.0001 factor为： 16 开始训练GMF_model
# Epoch 1/5, Accuracy: 80.49%, Loss in this epoch: 16072.662109375
# 测试集上的准确率为：94.36%
# HR: 0.460	NDCG: 0.257
# Epoch 2/5, Accuracy: 82.70%, Loss in this epoch: 12922.173828125
# 测试集上的准确率为：92.80%
# HR: 0.461	NDCG: 0.259
# Epoch 3/5, Accuracy: 82.62%, Loss in this epoch: 12796.724609375
# 测试集上的准确率为：92.26%
# HR: 0.463	NDCG: 0.260
# Epoch 4/5, Accuracy: 82.68%, Loss in this epoch: 12638.9423828125
# 测试集上的准确率为：92.00%
# HR: 0.470	NDCG: 0.265
# Epoch 5/5, Accuracy: 83.40%, Loss in this epoch: 12313.072265625
# 测试集上的准确率为：92.09%
# HR: 0.482	NDCG: 0.271
# 本次训练最高的HR为： 0.4821192052980132 最高的NDCG为： 0.27053851967175957
# 本次训练batch_size为： 128 lr为： 0.0001 factor为： 16 开始训练MLP_model
# Epoch 1/5, Accuracy: 81.88%, Loss in this epoch: 14260.2978515625
# 测试集上的准确率为：91.63%
# HR: 0.460	NDCG: 0.256
# Epoch 2/5, Accuracy: 83.33%, Loss in this epoch: 12720.060546875
# 测试集上的准确率为：91.52%
# HR: 0.457	NDCG: 0.255
# Epoch 3/5, Accuracy: 83.57%, Loss in this epoch: 12555.7978515625
# 测试集上的准确率为：92.48%
# HR: 0.461	NDCG: 0.256
# Epoch 4/5, Accuracy: 83.68%, Loss in this epoch: 12470.6513671875
# 测试集上的准确率为：93.42%
# HR: 0.464	NDCG: 0.259
# Epoch 5/5, Accuracy: 83.75%, Loss in this epoch: 12400.0419921875
# 测试集上的准确率为：92.26%
# HR: 0.463	NDCG: 0.258
# 本次训练最高的HR为： 0.4640728476821192 最高的NDCG为： 0.25856445094004993
# 本次训练batch_size为： 128 lr为： 0.0001 factor为： 16 开始训练NeuMF_model
# Epoch 1/5, Accuracy: 78.26%, Loss in this epoch: 19894.173828125
# 测试集上的准确率为：99.01%
# HR: 0.469	NDCG: 0.261
# Epoch 2/5, Accuracy: 78.22%, Loss in this epoch: 17852.671875
# 测试集上的准确率为：99.01%
# HR: 0.469	NDCG: 0.261
# Epoch 3/5, Accuracy: 78.22%, Loss in this epoch: 17385.837890625
# 测试集上的准确率为：99.01%
# HR: 0.469	NDCG: 0.261
# Epoch 4/5, Accuracy: 78.22%, Loss in this epoch: 17171.92578125
# 测试集上的准确率为：99.01%
# HR: 0.470	NDCG: 0.262
# Epoch 5/5, Accuracy: 78.22%, Loss in this epoch: 16995.9375
# 测试集上的准确率为：99.01%
# HR: 0.467	NDCG: 0.261
# 本次训练最高的HR为： 0.4698675496688742 最高的NDCG为： 0.2618172367395737
# 本次训练batch_size为： 128 lr为： 0.0001 factor为： 32 开始训练GMF_model
# Epoch 1/5, Accuracy: 80.85%, Loss in this epoch: 15724.7861328125
# 测试集上的准确率为：93.76%
# HR: 0.462	NDCG: 0.258
# Epoch 2/5, Accuracy: 82.98%, Loss in this epoch: 12691.591796875
# 测试集上的准确率为：92.72%
# HR: 0.482	NDCG: 0.269
# Epoch 3/5, Accuracy: 84.31%, Loss in this epoch: 11926.4736328125
# 测试集上的准确率为：92.69%
# HR: 0.505	NDCG: 0.281
# Epoch 4/5, Accuracy: 85.30%, Loss in this epoch: 11345.8232421875
# 测试集上的准确率为：92.87%
# HR: 0.522	NDCG: 0.292
# Epoch 5/5, Accuracy: 86.01%, Loss in this epoch: 10912.8125
# 测试集上的准确率为：93.13%
# HR: 0.544	NDCG: 0.301
# 本次训练最高的HR为： 0.5440397350993378 最高的NDCG为： 0.3009461798647148
# 本次训练batch_size为： 128 lr为： 0.0001 factor为： 32 开始训练MLP_model
# Epoch 1/5, Accuracy: 82.58%, Loss in this epoch: 13594.2470703125
# 测试集上的准确率为：93.19%
# HR: 0.464	NDCG: 0.256
# Epoch 2/5, Accuracy: 83.52%, Loss in this epoch: 12586.09765625
# 测试集上的准确率为：92.74%
# HR: 0.460	NDCG: 0.259
# Epoch 3/5, Accuracy: 83.74%, Loss in this epoch: 12419.056640625
# 测试集上的准确率为：92.81%
# HR: 0.461	NDCG: 0.256
# Epoch 4/5, Accuracy: 83.90%, Loss in this epoch: 12288.3046875
# 测试集上的准确率为：92.44%
# HR: 0.466	NDCG: 0.261
# Epoch 5/5, Accuracy: 84.06%, Loss in this epoch: 12167.806640625
# 测试集上的准确率为：92.85%
# HR: 0.466	NDCG: 0.262
# 本次训练最高的HR为： 0.46605960264900664 最高的NDCG为： 0.2618044388508078
# 本次训练batch_size为： 128 lr为： 0.0001 factor为： 32 开始训练NeuMF_model
# Epoch 1/5, Accuracy: 77.48%, Loss in this epoch: 21166.095703125
# 测试集上的准确率为：99.01%
# HR: 0.446	NDCG: 0.244
# Epoch 2/5, Accuracy: 78.22%, Loss in this epoch: 18536.3671875
# 测试集上的准确率为：99.01%
# HR: 0.457	NDCG: 0.253
# Epoch 3/5, Accuracy: 78.22%, Loss in this epoch: 17915.380859375
# 测试集上的准确率为：99.01%
# HR: 0.463	NDCG: 0.257
# Epoch 4/5, Accuracy: 78.22%, Loss in this epoch: 17648.6875
# 测试集上的准确率为：99.01%
# HR: 0.463	NDCG: 0.257
# Epoch 5/5, Accuracy: 78.22%, Loss in this epoch: 17458.19921875
# 测试集上的准确率为：99.01%
# HR: 0.463	NDCG: 0.258
# 本次训练最高的HR为： 0.46341059602649004 最高的NDCG为： 0.2582484725088227
# 本次训练batch_size为： 128 lr为： 0.0001 factor为： 64 开始训练GMF_model
# Epoch 1/5, Accuracy: 81.22%, Loss in this epoch: 15352.6533203125
# 测试集上的准确率为：93.12%
# HR: 0.460	NDCG: 0.258
# Epoch 2/5, Accuracy: 82.82%, Loss in this epoch: 12677.2783203125
# 测试集上的准确率为：92.39%
# HR: 0.476	NDCG: 0.268
# Epoch 3/5, Accuracy: 84.64%, Loss in this epoch: 11797.822265625
# 测试集上的准确率为：93.08%
# HR: 0.513	NDCG: 0.289
# Epoch 4/5, Accuracy: 85.95%, Loss in this epoch: 11002.70703125
# 测试集上的准确率为：93.45%
# HR: 0.551	NDCG: 0.307
# Epoch 5/5, Accuracy: 86.79%, Loss in this epoch: 10460.9130859375
# 测试集上的准确率为：93.64%
# HR: 0.573	NDCG: 0.321
# 本次训练最高的HR为： 0.5725165562913908 最高的NDCG为： 0.3213699749193181
# 本次训练batch_size为： 128 lr为： 0.0001 factor为： 64 开始训练MLP_model
# Epoch 1/5, Accuracy: 82.94%, Loss in this epoch: 13212.4091796875
# 测试集上的准确率为：92.97%
# HR: 0.453	NDCG: 0.254
# Epoch 2/5, Accuracy: 83.77%, Loss in this epoch: 12407.724609375
# 测试集上的准确率为：93.04%
# HR: 0.460	NDCG: 0.255
# Epoch 3/5, Accuracy: 84.27%, Loss in this epoch: 12070.3740234375
# 测试集上的准确率为：91.93%
# HR: 0.470	NDCG: 0.262
# Epoch 4/5, Accuracy: 85.16%, Loss in this epoch: 11519.5185546875
# 测试集上的准确率为：93.43%
# HR: 0.490	NDCG: 0.272
# Epoch 5/5, Accuracy: 86.05%, Loss in this epoch: 10944.701171875
# 测试集上的准确率为：92.38%
# HR: 0.507	NDCG: 0.279
# 本次训练最高的HR为： 0.5071192052980132 最高的NDCG为： 0.2787693755549461
# 本次训练batch_size为： 128 lr为： 0.0001 factor为： 64 开始训练NeuMF_model
# Epoch 1/5, Accuracy: 77.96%, Loss in this epoch: 20981.6328125
# 测试集上的准确率为：99.01%
# HR: 0.447	NDCG: 0.241
# Epoch 2/5, Accuracy: 78.22%, Loss in this epoch: 18374.09375
# 测试集上的准确率为：99.01%
# HR: 0.453	NDCG: 0.245
# Epoch 3/5, Accuracy: 78.22%, Loss in this epoch: 17769.876953125
# 测试集上的准确率为：99.01%
# HR: 0.455	NDCG: 0.246
# Epoch 4/5, Accuracy: 78.22%, Loss in this epoch: 17494.404296875
# 测试集上的准确率为：99.01%
# HR: 0.456	NDCG: 0.247
# Epoch 5/5, Accuracy: 78.22%, Loss in this epoch: 17264.4375
# 测试集上的准确率为：99.01%
# HR: 0.459	NDCG: 0.249
# 本次训练最高的HR为： 0.45927152317880793 最高的NDCG为： 0.248979254319324
# 本次训练batch_size为： 128 lr为： 0.0005 factor为： 8 开始训练GMF_model
# Epoch 1/5, Accuracy: 82.67%, Loss in this epoch: 13369.4296875
# 测试集上的准确率为：92.61%
# HR: 0.491	NDCG: 0.272
# Epoch 2/5, Accuracy: 85.30%, Loss in this epoch: 11363.9091796875
# 测试集上的准确率为：93.22%
# HR: 0.544	NDCG: 0.302
# Epoch 3/5, Accuracy: 86.44%, Loss in this epoch: 10634.3046875
# 测试集上的准确率为：93.49%
# HR: 0.573	NDCG: 0.322
# Epoch 4/5, Accuracy: 86.97%, Loss in this epoch: 10280.8359375
# 测试集上的准确率为：93.62%
# HR: 0.586	NDCG: 0.327
# Epoch 5/5, Accuracy: 87.44%, Loss in this epoch: 9978.7685546875
# 测试集上的准确率为：93.52%
# HR: 0.606	NDCG: 0.341
# 本次训练最高的HR为： 0.605794701986755 最高的NDCG为： 0.34100413340762437
# 本次训练batch_size为： 128 lr为： 0.0005 factor为： 8 开始训练MLP_model
# Epoch 1/5, Accuracy: 82.62%, Loss in this epoch: 13584.1376953125
# 测试集上的准确率为：92.05%
# HR: 0.465	NDCG: 0.260
# Epoch 2/5, Accuracy: 83.68%, Loss in this epoch: 12434.060546875
# 测试集上的准确率为：92.46%
# HR: 0.468	NDCG: 0.261
# Epoch 3/5, Accuracy: 83.81%, Loss in this epoch: 12324.32421875
# 测试集上的准确率为：92.93%
# HR: 0.465	NDCG: 0.260
# Epoch 4/5, Accuracy: 83.98%, Loss in this epoch: 12230.7060546875
# 测试集上的准确率为：93.59%
# HR: 0.476	NDCG: 0.264
# Epoch 5/5, Accuracy: 84.37%, Loss in this epoch: 12028.568359375
# 测试集上的准确率为：93.81%
# HR: 0.488	NDCG: 0.272
# 本次训练最高的HR为： 0.4880794701986755 最高的NDCG为： 0.27151413956845305
# 本次训练batch_size为： 128 lr为： 0.0005 factor为： 8 开始训练NeuMF_model
# Epoch 1/5, Accuracy: 77.41%, Loss in this epoch: 16166.8916015625
# 测试集上的准确率为：99.00%
# HR: 0.535	NDCG: 0.303
# Epoch 2/5, Accuracy: 81.69%, Loss in this epoch: 12723.4921875
# 测试集上的准确率为：95.64%
# HR: 0.515	NDCG: 0.294
# Epoch 3/5, Accuracy: 84.80%, Loss in this epoch: 12205.0322265625
# 测试集上的准确率为：93.64%
# HR: 0.512	NDCG: 0.293
# Epoch 4/5, Accuracy: 84.85%, Loss in this epoch: 12017.4345703125
# 测试集上的准确率为：93.21%
# HR: 0.515	NDCG: 0.294
# Epoch 5/5, Accuracy: 84.93%, Loss in this epoch: 11888.0576171875
# 测试集上的准确率为：93.09%
# HR: 0.518	NDCG: 0.295
# 本次训练最高的HR为： 0.534933774834437 最高的NDCG为： 0.3032240164780982
# 本次训练batch_size为： 128 lr为： 0.0005 factor为： 16 开始训练GMF_model
# Epoch 1/5, Accuracy: 82.39%, Loss in this epoch: 13358.8349609375
# 测试集上的准确率为：92.34%
# HR: 0.489	NDCG: 0.272
# Epoch 2/5, Accuracy: 85.83%, Loss in this epoch: 11121.7373046875
# 测试集上的准确率为：93.29%
# HR: 0.564	NDCG: 0.316
# Epoch 3/5, Accuracy: 87.24%, Loss in this epoch: 10175.0556640625
# 测试集上的准确率为：93.64%
# HR: 0.594	NDCG: 0.334
# Epoch 4/5, Accuracy: 87.91%, Loss in this epoch: 9724.1142578125
# 测试集上的准确率为：93.70%
# HR: 0.622	NDCG: 0.356
# Epoch 5/5, Accuracy: 88.47%, Loss in this epoch: 9361.3642578125
# 测试集上的准确率为：93.81%
# HR: 0.641	NDCG: 0.369
# 本次训练最高的HR为： 0.6413907284768212 最高的NDCG为： 0.3685433669695234
# 本次训练batch_size为： 128 lr为： 0.0005 factor为： 16 开始训练MLP_model
# Epoch 1/5, Accuracy: 83.02%, Loss in this epoch: 13047.03515625
# 测试集上的准确率为：92.26%
# HR: 0.464	NDCG: 0.260
# Epoch 2/5, Accuracy: 83.74%, Loss in this epoch: 12388.1513671875
# 测试集上的准确率为：93.53%
# HR: 0.468	NDCG: 0.259
# Epoch 3/5, Accuracy: 84.08%, Loss in this epoch: 12179.494140625
# 测试集上的准确率为：92.69%
# HR: 0.483	NDCG: 0.269
# Epoch 4/5, Accuracy: 84.97%, Loss in this epoch: 11582.1025390625
# 测试集上的准确率为：93.40%
# HR: 0.504	NDCG: 0.281
# Epoch 5/5, Accuracy: 85.67%, Loss in this epoch: 11154.10546875
# 测试集上的准确率为：93.10%
# HR: 0.530	NDCG: 0.293
# 本次训练最高的HR为： 0.5298013245033113 最高的NDCG为： 0.2925107338588148
# 本次训练batch_size为： 128 lr为： 0.0005 factor为： 16 开始训练NeuMF_model
# Epoch 1/5, Accuracy: 78.28%, Loss in this epoch: 15432.65234375
# 测试集上的准确率为：98.95%
# HR: 0.556	NDCG: 0.317
# Epoch 2/5, Accuracy: 82.73%, Loss in this epoch: 12319.873046875
# 测试集上的准确率为：96.02%
# HR: 0.538	NDCG: 0.310
# Epoch 3/5, Accuracy: 85.88%, Loss in this epoch: 11645.9736328125
# 测试集上的准确率为：94.35%
# HR: 0.537	NDCG: 0.309
# Epoch 4/5, Accuracy: 86.06%, Loss in this epoch: 11377.0458984375
# 测试集上的准确率为：93.94%
# HR: 0.540	NDCG: 0.309
# Epoch 5/5, Accuracy: 86.15%, Loss in this epoch: 11200.7802734375
# 测试集上的准确率为：93.78%
# HR: 0.545	NDCG: 0.312
# 本次训练最高的HR为： 0.5562913907284768 最高的NDCG为： 0.31655992488643736
# 本次训练batch_size为： 128 lr为： 0.0005 factor为： 32 开始训练GMF_model
# Epoch 1/5, Accuracy: 84.00%, Loss in this epoch: 12540.951171875
# 测试集上的准确率为：93.51%
# HR: 0.554	NDCG: 0.312
# Epoch 2/5, Accuracy: 87.04%, Loss in this epoch: 10294.8583984375
# 测试集上的准确率为：93.68%
# HR: 0.606	NDCG: 0.344
# Epoch 3/5, Accuracy: 88.08%, Loss in this epoch: 9623.80859375
# 测试集上的准确率为：93.82%
# HR: 0.634	NDCG: 0.362
# Epoch 4/5, Accuracy: 88.72%, Loss in this epoch: 9180.88671875
# 测试集上的准确率为：94.08%
# HR: 0.656	NDCG: 0.380
# Epoch 5/5, Accuracy: 89.29%, Loss in this epoch: 8785.224609375
# 测试集上的准确率为：94.09%
# HR: 0.664	NDCG: 0.390
# 本次训练最高的HR为： 0.6644039735099337 最高的NDCG为： 0.39037294319830923
# 本次训练batch_size为： 128 lr为： 0.0005 factor为： 32 开始训练MLP_model
# Epoch 1/5, Accuracy: 83.22%, Loss in this epoch: 12894.1494140625
# 测试集上的准确率为：92.10%
# HR: 0.464	NDCG: 0.259
# Epoch 2/5, Accuracy: 84.04%, Loss in this epoch: 12219.9951171875
# 测试集上的准确率为：93.39%
# HR: 0.489	NDCG: 0.271
# Epoch 3/5, Accuracy: 85.09%, Loss in this epoch: 11484.9560546875
# 测试集上的准确率为：92.33%
# HR: 0.517	NDCG: 0.284
# Epoch 4/5, Accuracy: 86.03%, Loss in this epoch: 10909.9013671875
# 测试集上的准确率为：93.33%
# HR: 0.556	NDCG: 0.307
# Epoch 5/5, Accuracy: 86.98%, Loss in this epoch: 10331.544921875
# 测试集上的准确率为：92.67%
# HR: 0.579	NDCG: 0.322
# 本次训练最高的HR为： 0.5793046357615894 最高的NDCG为： 0.3217757485308255
# 本次训练batch_size为： 128 lr为： 0.0005 factor为： 32 开始训练NeuMF_model
# Epoch 1/5, Accuracy: 79.06%, Loss in this epoch: 14892.732421875
# 测试集上的准确率为：98.38%
# HR: 0.492	NDCG: 0.274
# Epoch 2/5, Accuracy: 83.63%, Loss in this epoch: 12265.5478515625
# 测试集上的准确率为：94.60%
# HR: 0.499	NDCG: 0.279
# Epoch 3/5, Accuracy: 85.28%, Loss in this epoch: 11792.50390625
# 测试集上的准确率为：93.57%
# HR: 0.505	NDCG: 0.284
# Epoch 4/5, Accuracy: 85.52%, Loss in this epoch: 11542.455078125
# 测试集上的准确率为：93.40%
# HR: 0.513	NDCG: 0.289
# Epoch 5/5, Accuracy: 85.71%, Loss in this epoch: 11359.51953125
# 测试集上的准确率为：93.49%
# HR: 0.522	NDCG: 0.295
# 本次训练最高的HR为： 0.5218543046357615 最高的NDCG为： 0.29450184979111965
# 本次训练batch_size为： 128 lr为： 0.0005 factor为： 64 开始训练GMF_model
# Epoch 1/5, Accuracy: 84.68%, Loss in this epoch: 12124.3359375
# 测试集上的准确率为：93.84%
# HR: 0.581	NDCG: 0.328
# Epoch 2/5, Accuracy: 87.81%, Loss in this epoch: 9816.9873046875
# 测试集上的准确率为：93.90%
# HR: 0.630	NDCG: 0.360
# Epoch 3/5, Accuracy: 88.65%, Loss in this epoch: 9228.900390625
# 测试集上的准确率为：94.04%
# HR: 0.653	NDCG: 0.381
# Epoch 4/5, Accuracy: 89.24%, Loss in this epoch: 8819.3134765625
# 测试集上的准确率为：94.08%
# HR: 0.667	NDCG: 0.392
# Epoch 5/5, Accuracy: 89.83%, Loss in this epoch: 8412.2861328125
# 测试集上的准确率为：94.07%
# HR: 0.681	NDCG: 0.401
# 本次训练最高的HR为： 0.6809602649006623 最高的NDCG为： 0.4014736379940135
# 本次训练batch_size为： 128 lr为： 0.0005 factor为： 64 开始训练MLP_model
# Epoch 1/5, Accuracy: 83.39%, Loss in this epoch: 12766.82421875
# 测试集上的准确率为：92.44%
# HR: 0.470	NDCG: 0.262
# Epoch 2/5, Accuracy: 84.67%, Loss in this epoch: 11790.6181640625
# 测试集上的准确率为：92.89%
# HR: 0.509	NDCG: 0.282
# Epoch 3/5, Accuracy: 86.13%, Loss in this epoch: 10877.5986328125
# 测试集上的准确率为：92.25%
# HR: 0.566	NDCG: 0.317
# Epoch 4/5, Accuracy: 87.27%, Loss in this epoch: 10142.7978515625
# 测试集上的准确率为：93.08%
# HR: 0.600	NDCG: 0.337
# Epoch 5/5, Accuracy: 88.02%, Loss in this epoch: 9631.494140625
# 测试集上的准确率为：93.10%
# HR: 0.617	NDCG: 0.350
# 本次训练最高的HR为： 0.6172185430463576 最高的NDCG为： 0.3498799722741847
# 本次训练batch_size为： 128 lr为： 0.0005 factor为： 64 开始训练NeuMF_model
# Epoch 1/5, Accuracy: 78.95%, Loss in this epoch: 14583.509765625
# 测试集上的准确率为：96.73%
# HR: 0.477	NDCG: 0.268
# Epoch 2/5, Accuracy: 84.09%, Loss in this epoch: 12378.4228515625
# 测试集上的准确率为：93.71%
# HR: 0.481	NDCG: 0.274
# Epoch 3/5, Accuracy: 84.61%, Loss in this epoch: 12020.0087890625
# 测试集上的准确率为：93.28%
# HR: 0.487	NDCG: 0.278
# Epoch 4/5, Accuracy: 84.84%, Loss in this epoch: 11796.49609375
# 测试集上的准确率为：93.38%
# HR: 0.495	NDCG: 0.283
# Epoch 5/5, Accuracy: 85.10%, Loss in this epoch: 11599.9931640625
# 测试集上的准确率为：93.55%
# HR: 0.506	NDCG: 0.288
# 本次训练最高的HR为： 0.5059602649006623 最高的NDCG为： 0.28817599270631994
# 本次训练batch_size为： 128 lr为： 0.001 factor为： 8 开始训练GMF_model
# Epoch 1/5, Accuracy: 83.45%, Loss in this epoch: 12728.333984375
# 测试集上的准确率为：93.20%
# HR: 0.533	NDCG: 0.298
# Epoch 2/5, Accuracy: 86.60%, Loss in this epoch: 10593.775390625
# 测试集上的准确率为：93.54%
# HR: 0.590	NDCG: 0.332
# Epoch 3/5, Accuracy: 87.57%, Loss in this epoch: 9934.060546875
# 测试集上的准确率为：93.70%
# HR: 0.618	NDCG: 0.350
# Epoch 4/5, Accuracy: 87.96%, Loss in this epoch: 9667.3369140625
# 测试集上的准确率为：93.67%
# HR: 0.627	NDCG: 0.356
# Epoch 5/5, Accuracy: 88.09%, Loss in this epoch: 9562.0615234375
# 测试集上的准确率为：93.63%
# HR: 0.631	NDCG: 0.360
# 本次训练最高的HR为： 0.6311258278145695 最高的NDCG为： 0.35964998623737515
# 本次训练batch_size为： 128 lr为： 0.001 factor为： 8 开始训练MLP_model
# Epoch 1/5, Accuracy: 83.10%, Loss in this epoch: 12966.7626953125
# 测试集上的准确率为：92.27%
# HR: 0.461	NDCG: 0.259
# Epoch 2/5, Accuracy: 83.73%, Loss in this epoch: 12391.76953125
# 测试集上的准确率为：92.62%
# HR: 0.464	NDCG: 0.259
# Epoch 3/5, Accuracy: 84.31%, Loss in this epoch: 12060.8486328125
# 测试集上的准确率为：93.16%
# HR: 0.498	NDCG: 0.276
# Epoch 4/5, Accuracy: 85.17%, Loss in this epoch: 11462.927734375
# 测试集上的准确率为：93.34%
# HR: 0.519	NDCG: 0.286
# Epoch 5/5, Accuracy: 85.61%, Loss in this epoch: 11146.3349609375
# 测试集上的准确率为：92.61%
# HR: 0.536	NDCG: 0.297
# 本次训练最高的HR为： 0.5364238410596026 最高的NDCG为： 0.29671493179804076
# 本次训练batch_size为： 128 lr为： 0.001 factor为： 8 开始训练NeuMF_model
# Epoch 1/5, Accuracy: 84.48%, Loss in this epoch: 11779.138671875
# 测试集上的准确率为：95.34%
# HR: 0.605	NDCG: 0.344
# Epoch 2/5, Accuracy: 87.55%, Loss in this epoch: 10032.294921875
# 测试集上的准确率为：94.29%
# HR: 0.615	NDCG: 0.351
# Epoch 3/5, Accuracy: 87.88%, Loss in this epoch: 9764.7763671875
# 测试集上的准确率为：93.97%
# HR: 0.619	NDCG: 0.353
# Epoch 4/5, Accuracy: 87.99%, Loss in this epoch: 9657.361328125
# 测试集上的准确率为：93.85%
# HR: 0.621	NDCG: 0.355
# Epoch 5/5, Accuracy: 88.04%, Loss in this epoch: 9601.7568359375
# 测试集上的准确率为：93.77%
# HR: 0.622	NDCG: 0.356
# 本次训练最高的HR为： 0.6223509933774835 最高的NDCG为： 0.3555489955824367
# 本次训练batch_size为： 128 lr为： 0.001 factor为： 16 开始训练GMF_model
# Epoch 1/5, Accuracy: 84.73%, Loss in this epoch: 11978.5322265625
# 测试集上的准确率为：93.50%
# HR: 0.582	NDCG: 0.328
# Epoch 2/5, Accuracy: 87.49%, Loss in this epoch: 10006.548828125
# 测试集上的准确率为：93.65%
# HR: 0.621	NDCG: 0.356
# Epoch 3/5, Accuracy: 88.32%, Loss in this epoch: 9444.21484375
# 测试集上的准确率为：93.86%
# HR: 0.642	NDCG: 0.372
# Epoch 4/5, Accuracy: 88.76%, Loss in this epoch: 9134.9130859375
# 测试集上的准确率为：93.83%
# HR: 0.650	NDCG: 0.382
# Epoch 5/5, Accuracy: 89.07%, Loss in this epoch: 8922.068359375
# 测试集上的准确率为：93.99%
# HR: 0.663	NDCG: 0.390
# 本次训练最高的HR为： 0.6627483443708609 最高的NDCG为： 0.3897915757793577
# 本次训练batch_size为： 128 lr为： 0.001 factor为： 16 开始训练MLP_model
# Epoch 1/5, Accuracy: 83.30%, Loss in this epoch: 12807.1669921875
# 测试集上的准确率为：92.50%
# HR: 0.464	NDCG: 0.262
# Epoch 2/5, Accuracy: 83.97%, Loss in this epoch: 12256.3759765625
# 测试集上的准确率为：92.74%
# HR: 0.488	NDCG: 0.269
# Epoch 3/5, Accuracy: 85.13%, Loss in this epoch: 11489.6201171875
# 测试集上的准确率为：93.23%
# HR: 0.520	NDCG: 0.292
# Epoch 4/5, Accuracy: 86.08%, Loss in this epoch: 10905.720703125
# 测试集上的准确率为：93.64%
# HR: 0.561	NDCG: 0.313
# Epoch 5/5, Accuracy: 86.85%, Loss in this epoch: 10397.3681640625
# 测试集上的准确率为：93.51%
# HR: 0.592	NDCG: 0.327
# 本次训练最高的HR为： 0.5922185430463576 最高的NDCG为： 0.32722283562587895
# 本次训练batch_size为： 128 lr为： 0.001 factor为： 16 开始训练NeuMF_model
# Epoch 1/5, Accuracy: 83.90%, Loss in this epoch: 12119.3544921875
# 测试集上的准确率为：94.63%
# HR: 0.573	NDCG: 0.330
# Epoch 2/5, Accuracy: 87.12%, Loss in this epoch: 10436.5029296875
# 测试集上的准确率为：94.52%
# HR: 0.601	NDCG: 0.349
# Epoch 3/5, Accuracy: 87.78%, Loss in this epoch: 9937.4013671875
# 测试集上的准确率为：94.48%
# HR: 0.620	NDCG: 0.361
# Epoch 4/5, Accuracy: 88.15%, Loss in this epoch: 9633.6533203125
# 测试集上的准确率为：94.37%
# HR: 0.632	NDCG: 0.368
# Epoch 5/5, Accuracy: 88.39%, Loss in this epoch: 9433.26171875
# 测试集上的准确率为：94.26%
# HR: 0.639	NDCG: 0.373
# 本次训练最高的HR为： 0.6389072847682119 最高的NDCG为： 0.37280474568004107
# 本次训练batch_size为： 128 lr为： 0.001 factor为： 32 开始训练GMF_model
# Epoch 1/5, Accuracy: 85.15%, Loss in this epoch: 11703.7216796875
# 测试集上的准确率为：93.69%
# HR: 0.599	NDCG: 0.342
# Epoch 2/5, Accuracy: 88.05%, Loss in this epoch: 9645.0166015625
# 测试集上的准确率为：93.91%
# HR: 0.645	NDCG: 0.373
# Epoch 3/5, Accuracy: 88.70%, Loss in this epoch: 9191.42578125
# 测试集上的准确率为：93.97%
# HR: 0.660	NDCG: 0.385
# Epoch 4/5, Accuracy: 89.09%, Loss in this epoch: 8921.2099609375
# 测试集上的准确率为：94.02%
# HR: 0.667	NDCG: 0.394
# Epoch 5/5, Accuracy: 89.46%, Loss in this epoch: 8661.7646484375
# 测试集上的准确率为：94.02%
# HR: 0.676	NDCG: 0.398
# 本次训练最高的HR为： 0.6763245033112583 最高的NDCG为： 0.39781360411697836
# 本次训练batch_size为： 128 lr为： 0.001 factor为： 32 开始训练MLP_model
# Epoch 1/5, Accuracy: 83.39%, Loss in this epoch: 12734.5732421875
# 测试集上的准确率为：93.38%
# HR: 0.466	NDCG: 0.258
# Epoch 2/5, Accuracy: 84.69%, Loss in this epoch: 11785.8046875
# 测试集上的准确率为：92.05%
# HR: 0.513	NDCG: 0.286
# Epoch 3/5, Accuracy: 85.93%, Loss in this epoch: 10996.775390625
# 测试集上的准确率为：92.81%
# HR: 0.563	NDCG: 0.316
# Epoch 4/5, Accuracy: 87.02%, Loss in this epoch: 10277.869140625
# 测试集上的准确率为：93.06%
# HR: 0.600	NDCG: 0.339
# Epoch 5/5, Accuracy: 87.78%, Loss in this epoch: 9771.3896484375
# 测试集上的准确率为：93.44%
# HR: 0.614	NDCG: 0.350
# 本次训练最高的HR为： 0.6135761589403973 最高的NDCG为： 0.34966032579933976
# 本次训练batch_size为： 128 lr为： 0.001 factor为： 32 开始训练NeuMF_model
# Epoch 1/5, Accuracy: 85.25%, Loss in this epoch: 11631.0517578125
# 测试集上的准确率为：94.66%
# HR: 0.580	NDCG: 0.333
# Epoch 2/5, Accuracy: 87.32%, Loss in this epoch: 10309.466796875
# 测试集上的准确率为：94.35%
# HR: 0.602	NDCG: 0.348
# Epoch 3/5, Accuracy: 87.95%, Loss in this epoch: 9869.9521484375
# 测试集上的准确率为：94.34%
# HR: 0.617	NDCG: 0.357
# Epoch 4/5, Accuracy: 88.31%, Loss in this epoch: 9595.177734375
# 测试集上的准确率为：94.32%
# HR: 0.626	NDCG: 0.364
# Epoch 5/5, Accuracy: 88.57%, Loss in this epoch: 9392.642578125
# 测试集上的准确率为：94.38%
# HR: 0.636	NDCG: 0.371
# 本次训练最高的HR为： 0.6359271523178808 最高的NDCG为： 0.3706639302739712
# 本次训练batch_size为： 128 lr为： 0.001 factor为： 64 开始训练GMF_model
# Epoch 1/5, Accuracy: 85.65%, Loss in this epoch: 11403.5693359375
# 测试集上的准确率为：94.03%
# HR: 0.631	NDCG: 0.361
# Epoch 2/5, Accuracy: 88.65%, Loss in this epoch: 9251.140625
# 测试集上的准确率为：94.08%
# HR: 0.666	NDCG: 0.388
# Epoch 3/5, Accuracy: 89.35%, Loss in this epoch: 8749.8125
# 测试集上的准确率为：94.14%
# HR: 0.678	NDCG: 0.400
# Epoch 4/5, Accuracy: 89.84%, Loss in this epoch: 8412.8310546875
# 测试集上的准确率为：94.35%
# HR: 0.684	NDCG: 0.404
# Epoch 5/5, Accuracy: 90.31%, Loss in this epoch: 8075.13232421875
# 测试集上的准确率为：94.05%
# HR: 0.686	NDCG: 0.406
# 本次训练最高的HR为： 0.6862582781456954 最高的NDCG为： 0.4059363080126646
# 本次训练batch_size为： 128 lr为： 0.001 factor为： 64 开始训练MLP_model
# Epoch 1/5, Accuracy: 83.54%, Loss in this epoch: 12635.7060546875
# 测试集上的准确率为：92.95%
# HR: 0.485	NDCG: 0.270
# Epoch 2/5, Accuracy: 85.14%, Loss in this epoch: 11489.9296875
# 测试集上的准确率为：92.93%
# HR: 0.545	NDCG: 0.305
# Epoch 3/5, Accuracy: 86.60%, Loss in this epoch: 10585.3466796875
# 测试集上的准确率为：93.54%
# HR: 0.593	NDCG: 0.330
# Epoch 4/5, Accuracy: 87.61%, Loss in this epoch: 9884.5166015625
# 测试集上的准确率为：93.99%
# HR: 0.621	NDCG: 0.356
# Epoch 5/5, Accuracy: 88.34%, Loss in this epoch: 9384.9580078125
# 测试集上的准确率为：93.71%
# HR: 0.640	NDCG: 0.369
# 本次训练最高的HR为： 0.6399006622516556 最高的NDCG为： 0.3694364588899866
# 本次训练batch_size为： 128 lr为： 0.001 factor为： 64 开始训练NeuMF_model
# Epoch 1/5, Accuracy: 85.12%, Loss in this epoch: 11648.953125
# 测试集上的准确率为：94.52%
# HR: 0.581	NDCG: 0.331
# Epoch 2/5, Accuracy: 87.55%, Loss in this epoch: 10145.8671875
# 测试集上的准确率为：94.08%
# HR: 0.608	NDCG: 0.353
# Epoch 3/5, Accuracy: 88.50%, Loss in this epoch: 9564.47265625
# 测试集上的准确率为：94.15%
# HR: 0.629	NDCG: 0.367
# Epoch 4/5, Accuracy: 89.03%, Loss in this epoch: 9194.298828125
# 测试集上的准确率为：94.24%
# HR: 0.636	NDCG: 0.375
# Epoch 5/5, Accuracy: 89.38%, Loss in this epoch: 8922.4931640625
# 测试集上的准确率为：94.24%
# HR: 0.648	NDCG: 0.382
# 本次训练最高的HR为： 0.6476821192052981 最高的NDCG为： 0.38226878404436127
# 本次训练batch_size为： 128 lr为： 0.005 factor为： 8 开始训练GMF_model
# Epoch 1/5, Accuracy: 84.91%, Loss in this epoch: 11769.0341796875
# 测试集上的准确率为：93.83%
# HR: 0.583	NDCG: 0.331
# Epoch 2/5, Accuracy: 87.33%, Loss in this epoch: 10109.65234375
# 测试集上的准确率为：93.90%
# HR: 0.617	NDCG: 0.351
# Epoch 3/5, Accuracy: 87.74%, Loss in this epoch: 9819.8486328125
# 测试集上的准确率为：93.64%
# HR: 0.628	NDCG: 0.359
# Epoch 4/5, Accuracy: 87.86%, Loss in this epoch: 9726.9853515625
# 测试集上的准确率为：93.74%
# HR: 0.635	NDCG: 0.362
# Epoch 5/5, Accuracy: 87.92%, Loss in this epoch: 9689.40234375
# 测试集上的准确率为：93.46%
# HR: 0.622	NDCG: 0.358
# 本次训练最高的HR为： 0.6350993377483444 最高的NDCG为： 0.3622692844219454
# 本次训练batch_size为： 128 lr为： 0.005 factor为： 8 开始训练MLP_model
# Epoch 1/5, Accuracy: 83.34%, Loss in this epoch: 12753.1513671875
# 测试集上的准确率为：93.13%
# HR: 0.463	NDCG: 0.257
# Epoch 2/5, Accuracy: 84.62%, Loss in this epoch: 11926.3779296875
# 测试集上的准确率为：93.62%
# HR: 0.525	NDCG: 0.288
# Epoch 3/5, Accuracy: 85.71%, Loss in this epoch: 11142.388671875
# 测试集上的准确率为：94.04%
# HR: 0.551	NDCG: 0.304
# Epoch 4/5, Accuracy: 86.84%, Loss in this epoch: 10451.0322265625
# 测试集上的准确率为：92.93%
# HR: 0.598	NDCG: 0.337
# Epoch 5/5, Accuracy: 87.60%, Loss in this epoch: 9921.8056640625
# 测试集上的准确率为：93.69%
# HR: 0.623	NDCG: 0.354
# 本次训练最高的HR为： 0.6231788079470199 最高的NDCG为： 0.35359263682732717
# 本次训练batch_size为： 128 lr为： 0.005 factor为： 8 开始训练NeuMF_model
# Epoch 1/5, Accuracy: 88.27%, Loss in this epoch: 9393.083984375
# 测试集上的准确率为：93.56%
# HR: 0.631	NDCG: 0.364
# Epoch 2/5, Accuracy: 88.38%, Loss in this epoch: 9312.7138671875
# 测试集上的准确率为：93.74%
# HR: 0.633	NDCG: 0.363
# Epoch 3/5, Accuracy: 88.40%, Loss in this epoch: 9298.96484375
# 测试集上的准确率为：93.55%
# HR: 0.635	NDCG: 0.366
# Epoch 4/5, Accuracy: 88.43%, Loss in this epoch: 9277.884765625
# 测试集上的准确率为：93.45%
# HR: 0.638	NDCG: 0.367
# Epoch 5/5, Accuracy: 88.47%, Loss in this epoch: 9250.39453125
# 测试集上的准确率为：93.55%
# HR: 0.637	NDCG: 0.367
# 本次训练最高的HR为： 0.6375827814569537 最高的NDCG为： 0.3670074052274717
# 本次训练batch_size为： 128 lr为： 0.005 factor为： 16 开始训练GMF_model
# Epoch 1/5, Accuracy: 85.50%, Loss in this epoch: 11435.5595703125
# 测试集上的准确率为：93.84%
# HR: 0.618	NDCG: 0.351
# Epoch 2/5, Accuracy: 88.13%, Loss in this epoch: 9607.5068359375
# 测试集上的准确率为：94.22%
# HR: 0.643	NDCG: 0.371
# Epoch 3/5, Accuracy: 88.61%, Loss in this epoch: 9263.5283203125
# 测试集上的准确率为：93.89%
# HR: 0.658	NDCG: 0.384
# Epoch 4/5, Accuracy: 88.81%, Loss in this epoch: 9120.359375
# 测试集上的准确率为：94.16%
# HR: 0.665	NDCG: 0.390
# Epoch 5/5, Accuracy: 88.93%, Loss in this epoch: 9048.923828125
# 测试集上的准确率为：93.86%
# HR: 0.669	NDCG: 0.388
# 本次训练最高的HR为： 0.6685430463576159 最高的NDCG为： 0.39006223012972363
# 本次训练batch_size为： 128 lr为： 0.005 factor为： 16 开始训练MLP_model
# Epoch 1/5, Accuracy: 83.58%, Loss in this epoch: 12609.19140625
# 测试集上的准确率为：93.53%
# HR: 0.499	NDCG: 0.273
# Epoch 2/5, Accuracy: 85.11%, Loss in this epoch: 11480.6962890625
# 测试集上的准确率为：92.52%
# HR: 0.548	NDCG: 0.308
# Epoch 3/5, Accuracy: 86.35%, Loss in this epoch: 10696.58984375
# 测试集上的准确率为：93.25%
# HR: 0.587	NDCG: 0.328
# Epoch 4/5, Accuracy: 87.12%, Loss in this epoch: 10157.7138671875
# 测试集上的准确率为：94.07%
# HR: 0.621	NDCG: 0.349
# Epoch 5/5, Accuracy: 87.67%, Loss in this epoch: 9775.3193359375
# 测试集上的准确率为：93.45%
# HR: 0.627	NDCG: 0.360
# 本次训练最高的HR为： 0.6268211920529801 最高的NDCG为： 0.35995244885246197
# 本次训练batch_size为： 128 lr为： 0.005 factor为： 16 开始训练NeuMF_model
# Epoch 1/5, Accuracy: 89.58%, Loss in this epoch: 8538.576171875
# 测试集上的准确率为：93.92%
# HR: 0.668	NDCG: 0.391
# Epoch 2/5, Accuracy: 89.65%, Loss in this epoch: 8484.064453125
# 测试集上的准确率为：93.98%
# HR: 0.672	NDCG: 0.392
# Epoch 3/5, Accuracy: 89.66%, Loss in this epoch: 8474.5234375
# 测试集上的准确率为：93.89%
# HR: 0.668	NDCG: 0.390
# Epoch 4/5, Accuracy: 89.66%, Loss in this epoch: 8467.7275390625
# 测试集上的准确率为：93.93%
# HR: 0.670	NDCG: 0.390
# Epoch 5/5, Accuracy: 89.67%, Loss in this epoch: 8460.451171875
# 测试集上的准确率为：94.03%
# HR: 0.674	NDCG: 0.392
# 本次训练最高的HR为： 0.6736754966887417 最高的NDCG为： 0.3922825214539107
# 本次训练batch_size为： 128 lr为： 0.005 factor为： 32 开始训练GMF_model
# Epoch 1/5, Accuracy: 85.71%, Loss in this epoch: 11289.0517578125
# 测试集上的准确率为：93.85%
# HR: 0.628	NDCG: 0.360
# Epoch 2/5, Accuracy: 88.51%, Loss in this epoch: 9362.8974609375
# 测试集上的准确率为：94.23%
# HR: 0.659	NDCG: 0.387
# Epoch 3/5, Accuracy: 89.12%, Loss in this epoch: 8938.744140625
# 测试集上的准确率为：94.29%
# HR: 0.673	NDCG: 0.395
# Epoch 4/5, Accuracy: 89.46%, Loss in this epoch: 8708.4658203125
# 测试集上的准确率为：94.26%
# HR: 0.679	NDCG: 0.403
# Epoch 5/5, Accuracy: 89.67%, Loss in this epoch: 8546.2333984375
# 测试集上的准确率为：94.01%
# HR: 0.682	NDCG: 0.406
# 本次训练最高的HR为： 0.6822847682119205 最高的NDCG为： 0.40594027415043793
# 本次训练batch_size为： 128 lr为： 0.005 factor为： 32 开始训练MLP_model
# Epoch 1/5, Accuracy: 83.61%, Loss in this epoch: 12589.794921875
# 测试集上的准确率为：93.79%
# HR: 0.504	NDCG: 0.276
# Epoch 2/5, Accuracy: 85.10%, Loss in this epoch: 11503.3369140625
# 测试集上的准确率为：92.21%
# HR: 0.557	NDCG: 0.308
# Epoch 3/5, Accuracy: 86.14%, Loss in this epoch: 10807.060546875
# 测试集上的准确率为：93.82%
# HR: 0.574	NDCG: 0.318
# Epoch 4/5, Accuracy: 86.50%, Loss in this epoch: 10515.05859375
# 测试集上的准确率为：92.36%
# HR: 0.584	NDCG: 0.326
# Epoch 5/5, Accuracy: 86.80%, Loss in this epoch: 10318.79296875
# 测试集上的准确率为：92.31%
# HR: 0.602	NDCG: 0.339
# 本次训练最高的HR为： 0.6018211920529801 最高的NDCG为： 0.33850193979666604
# 本次训练batch_size为： 128 lr为： 0.005 factor为： 32 开始训练NeuMF_model
# Epoch 1/5, Accuracy: 90.72%, Loss in this epoch: 7747.88623046875
# 测试集上的准确率为：93.90%
# HR: 0.684	NDCG: 0.407
# Epoch 2/5, Accuracy: 90.86%, Loss in this epoch: 7645.1982421875
# 测试集上的准确率为：93.69%
# HR: 0.686	NDCG: 0.407
# Epoch 3/5, Accuracy: 90.87%, Loss in this epoch: 7636.60595703125
# 测试集上的准确率为：93.94%
# HR: 0.684	NDCG: 0.407
# Epoch 4/5, Accuracy: 90.88%, Loss in this epoch: 7629.1767578125
# 测试集上的准确率为：93.88%
# HR: 0.682	NDCG: 0.404

# %% [markdown]
# # (2)第二问

# %% [markdown]
# 根据MLP的代码，如果layer的len为1，则嵌入层之后，隐藏层为a*a的方阵，但文章中说MLP-0是嵌入层然后直接输出预测，所以就是，所以我们直接

# %%
batch_size = 1024
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4)
validation_loader = DataLoader(validation_dataset, batch_size=64, shuffle=True, num_workers=1)
test_loader = DataLoader(test_dataset, batch_size=101, shuffle=False, num_workers=1)
    
for n in range(0, 1): # n为几层隐藏层，4代表3个隐藏层
    for factor in factors:

        lr = 0.005 # 得根据上面的结果定
        
        loss_function = nn.BCEWithLogitsLoss() # 定义损失函数
        
        layers =  [factor*(2**i) for i in reversed(range(n+1))] # range里面的数代表几层隐藏层，4代表3层
        reg_layers = [0] * (n+1)
        droupout = [0] * (n+1)
        
        MLP_model = MLP(UserID_num+1, MovieID_num+1, layers, reg_layers, droupout)
        
        print("本次训练batch_size为：", batch_size, "lr为：", lr, "factor为：", factor, "开始训练MLP_model")
        optimizer = optim.Adam(MLP_model.parameters(), lr=lr) # 定义优化器
        training_model(MLP_model, train_loader, test_loader, 20, 10, batch_size, lr, factor) # 训练20个epoch
# Out:
# 本次训练batch_size为： 1024 lr为： 0.005 factor为： 8 开始训练MLP_model
# Epoch 1/20, Accuracy: 82.86%, Loss in this epoch: 1648.0091552734375
# 测试集上的准确率为：92.50%
# HR: 0.462	NDCG: 0.255
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Epoch 2/20, Accuracy: 83.53%, Loss in this epoch: 1570.5020751953125
# 测试集上的准确率为：92.69%
# HR: 0.463	NDCG: 0.260
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0><function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#         self._shutdown_workers()self._shutdown_workers()
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#         if w.is_alive():if w.is_alive():
#
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# assert self._parent_pid == os.getpid(), 'can only test a child process'AssertionError
# : AssertionErrorcan only test a child process
# : can only test a child process
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0><function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#         self._shutdown_workers()self._shutdown_workers()
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#         if w.is_alive():if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#         assert self._parent_pid == os.getpid(), 'can only test a child process'assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError
# AssertionError: : can only test a child processcan only test a child process
#
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0><function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#         self._shutdown_workers()self._shutdown_workers()
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#         if w.is_alive():if w.is_alive():
#
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#         assert self._parent_pid == os.getpid(), 'can only test a child process'assert self._parent_pid == os.getpid(), 'can only test a child process'
#
# AssertionErrorAssertionError: : can only test a child processcan only test a child process
#
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0><function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#         self._shutdown_workers()self._shutdown_workers()
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#         if w.is_alive():if w.is_alive():
#
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#         assert self._parent_pid == os.getpid(), 'can only test a child process'assert self._parent_pid == os.getpid(), 'can only test a child process'
#
# AssertionErrorAssertionError: : can only test a child processcan only test a child process
# Epoch 3/20, Accuracy: 83.58%, Loss in this epoch: 1563.822265625
# 测试集上的准确率为：92.65%
# HR: 0.464	NDCG: 0.260
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#       File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
# Exception ignored in:   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
#     Traceback (most recent call last):
# self._shutdown_workers()  File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#
#       File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
# self._shutdown_workers()
# if w.is_alive():
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#         if w.is_alive():assert self._parent_pid == os.getpid(), 'can only test a child process'
#
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# AssertionError    : assert self._parent_pid == os.getpid(), 'can only test a child process'can only test a child process
#
# AssertionError: can only test a child process
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0><function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#         self._shutdown_workers()self._shutdown_workers()
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#         if w.is_alive():
# if w.is_alive():  File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
#       File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# assert self._parent_pid == os.getpid(), 'can only test a child process'    assert self._parent_pid == os.getpid(), 'can only test a child process'
#
# AssertionError: AssertionError: can only test a child processcan only test a child process
#
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0><function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#         self._shutdown_workers()self._shutdown_workers()
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#         if w.is_alive():if w.is_alive():
#
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#         assert self._parent_pid == os.getpid(), 'can only test a child process'assert self._parent_pid == os.getpid(), 'can only test a child process'
#
# AssertionErrorAssertionError: : can only test a child processcan only test a child process
#
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0><function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#         self._shutdown_workers()self._shutdown_workers()
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#         if w.is_alive():if w.is_alive():
#
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#         assert self._parent_pid == os.getpid(), 'can only test a child process'assert self._parent_pid == os.getpid(), 'can only test a child process'
#
# AssertionErrorAssertionError: : can only test a child processcan only test a child process
# Epoch 4/20, Accuracy: 83.66%, Loss in this epoch: 1555.035888671875
# 测试集上的准确率为：93.09%
# HR: 0.467	NDCG: 0.263
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0><function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#         self._shutdown_workers()self._shutdown_workers()
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#         if w.is_alive():if w.is_alive():
#
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# assert self._parent_pid == os.getpid(), 'can only test a child process'AssertionError
# : can only test a child processAssertionError:
# can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0><function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#         self._shutdown_workers()self._shutdown_workers()
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
# if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#       File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# assert self._parent_pid == os.getpid(), 'can only test a child process'AssertionError
# : AssertionErrorcan only test a child process:
# can only test a child process
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0><function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#         self._shutdown_workers()self._shutdown_workers()
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#         if w.is_alive():if w.is_alive():
#
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#         assert self._parent_pid == os.getpid(), 'can only test a child process'assert self._parent_pid == os.getpid(), 'can only test a child process'
#
# AssertionErrorAssertionError: : can only test a child processcan only test a child process
#
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>Exception ignored in:
# Traceback (most recent call last):
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>  File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#
#     Traceback (most recent call last):
# self._shutdown_workers()  File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     self._shutdown_workers()    if w.is_alive():
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#         if w.is_alive():assert self._parent_pid == os.getpid(), 'can only test a child process'
#
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# AssertionError    : assert self._parent_pid == os.getpid(), 'can only test a child process'can only test a child process
#
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Epoch 5/20, Accuracy: 83.78%, Loss in this epoch: 1545.3404541015625
# 测试集上的准确率为：92.27%
# HR: 0.466	NDCG: 0.261
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
# Exception ignored in:   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>Exception ignored in:     self._shutdown_workers()
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     Traceback (most recent call last):
#     if w.is_alive():  File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#
#       File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     assert self._parent_pid == os.getpid(), 'can only test a child process'self._shutdown_workers()
#
# if w.is_alive():AssertionError  File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#
# :       File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# can only test a child processif w.is_alive():
#
# assert self._parent_pid == os.getpid(), 'can only test a child process'  File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
#     AssertionErrorassert self._parent_pid == os.getpid(), 'can only test a child process':
# can only test a child processAssertionError
# : can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>    Exception ignored in:
# self._shutdown_workers()<function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>Traceback (most recent call last):
#
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
# Traceback (most recent call last):
#       File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     if w.is_alive():self._shutdown_workers()
#
# self._shutdown_workers()  File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#
#     assert self._parent_pid == os.getpid(), 'can only test a child process'  File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#
# if w.is_alive():    AssertionError
# if w.is_alive()::   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
# can only test a child process      File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
# assert self._parent_pid == os.getpid(), 'can only test a child process'
# assert self._parent_pid == os.getpid(), 'can only test a child process'AssertionError
# : AssertionErrorcan only test a child process:
# can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0><function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# self._shutdown_workers()
# Traceback (most recent call last):
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#             self._shutdown_workers()if w.is_alive():self._shutdown_workers()
#
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#         if w.is_alive():assert self._parent_pid == os.getpid(), 'can only test a child process'
# if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# AssertionError
#     :   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# assert self._parent_pid == os.getpid(), 'can only test a child process'can only test a child process
#
# assert self._parent_pid == os.getpid(), 'can only test a child process'AssertionError
# : AssertionErrorcan only test a child process:
# can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>Exception ignored in: Exception ignored in:
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>Traceback (most recent call last):
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>  File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
# Traceback (most recent call last):
#     self._shutdown_workers()      File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#
# self._shutdown_workers()  File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#
#       File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
# self._shutdown_workers()if w.is_alive():
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
# if w.is_alive():  File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
#     if w.is_alive():  File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# assert self._parent_pid == os.getpid(), 'can only test a child process'
#
# assert self._parent_pid == os.getpid(), 'can only test a child process'  File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# AssertionError
# assert self._parent_pid == os.getpid(), 'can only test a child process': AssertionErrorcan only test a child process
# :
# AssertionErrorcan only test a child process
# : can only test a child process
# Epoch 6/20, Accuracy: 83.96%, Loss in this epoch: 1533.962646484375
# 测试集上的准确率为：93.35%
# HR: 0.477	NDCG: 0.266
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'Exception ignored in:
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>AssertionError
# : Traceback (most recent call last):
# can only test a child process  File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child processException ignored in:
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Epoch 7/20, Accuracy: 84.16%, Loss in this epoch: 1521.4627685546875
# 测试集上的准确率为：93.01%
# HR: 0.481	NDCG: 0.269
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: Exception ignored in: can only test a child process<function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     Exception ignored in: if w.is_alive():
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# Traceback (most recent call last):
#       File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     assert self._parent_pid == os.getpid(), 'can only test a child process'self._shutdown_workers()
#
# AssertionError  File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
# :     can only test a child processif w.is_alive():
#
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: Exception ignored in: can only test a child process<function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Epoch 8/20, Accuracy: 84.33%, Loss in this epoch: 1510.976806640625
# 测试集上的准确率为：93.58%
# HR: 0.490	NDCG: 0.275
# Exception ignored in:
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Epoch 9/20, Accuracy: 84.46%, Loss in this epoch: 1501.626708984375
# 测试集上的准确率为：93.04%
# HR: 0.502	NDCG: 0.280
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0><function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#         self._shutdown_workers()self._shutdown_workers()
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#         if w.is_alive():if w.is_alive():
#
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#         assert self._parent_pid == os.getpid(), 'can only test a child process'assert self._parent_pid == os.getpid(), 'can only test a child process'
#
# AssertionErrorAssertionError: : can only test a child processcan only test a child process
#
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0><function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#         self._shutdown_workers()self._shutdown_workers()
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#         if w.is_alive():if w.is_alive():
#
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#         assert self._parent_pid == os.getpid(), 'can only test a child process'assert self._parent_pid == os.getpid(), 'can only test a child process'
#
# AssertionErrorAssertionError: : can only test a child processcan only test a child process
#
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>Exception ignored in:
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
# Traceback (most recent call last):
#       File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
# self._shutdown_workers()
#       File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
# self._shutdown_workers()
#       File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
# if w.is_alive():
#       File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
# if w.is_alive():
# assert self._parent_pid == os.getpid(), 'can only test a child process'  File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#
#     AssertionErrorassert self._parent_pid == os.getpid(), 'can only test a child process':
# can only test a child processAssertionError
# : can only test a child process
# Exception ignored in: Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0><function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#         self._shutdown_workers()self._shutdown_workers()
#
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#         if w.is_alive():if w.is_alive():
#
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#         assert self._parent_pid == os.getpid(), 'can only test a child process'assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError
# : AssertionErrorcan only test a child process:
# can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Epoch 10/20, Accuracy: 84.59%, Loss in this epoch: 1492.7564697265625
# 测试集上的准确率为：93.15%
# HR: 0.500	NDCG: 0.279
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
#
# AssertionErrorTraceback (most recent call last):
# :   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
# can only test a child process
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fdaf819dbd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Epoch 11/20, Accuracy: 84.69%, Loss in this epoch: 1484.5880126953125
# 测试集上的准确率为：93.42%
# HR: 0.505	NDCG: 0.282

# %% [markdown]
# # 节省内存的小技巧

# %% [markdown]
# **ncf-pytorch中的读写数据，使用usecols**
# ```python
# ratings_test = pd.read_csv('ml-1m/ratings.dat', sep='::', header = None, names=["UserID", "MovieID"], usecols=[0, 1], dtype={0: np.int32, 1: np.int32})
# # usecols=[0, 1]：指定了仅使用数据文件中的第 0 列和第 1 列，即 'user' 和 'item' 列。这样做可以节省内存，加快数据加载速度。
# ratings_test.head(5)
# ```

# %%
ratings_test = pd.read_csv('ml-1m/ratings.dat', sep='::', header = None, names=["UserID", "item"], usecols=[0, 1], dtype={0: np.int32, 1: np.int32})
# usecols=[0, 1]：指定了仅使用数据文件中的第 0 列和第 1 列，即 'user' 和 'item' 列。这样做可以节省内存，加快数据加载速度。
ratings_test.head(5)

# %%
a = 1
b = 25
ratings_test[(ratings_test['UserID'] == a) & (ratings_test['item'] == b)]

# %%
import scipy.sparse as sp

import torch.utils.data as data

user_num = ratings_test['UserID'].max() + 1
item_num = ratings_test['item'].max() + 1

ratings_test_list = ratings_test.values.tolist()

# load ratings as a dok matrix
train_mat = sp.dok_matrix((user_num, item_num), dtype=np.float32)

for x in ratings_test_list:
    train_mat[x[0], x[1]] = 1.0
