# %%
import matplotlib.pyplot as plt

# Data for each model
epochs = list(range(20))

# GMF data
gmf_hr = [0.4856, 0.5636, 0.5998, 0.6157, 0.6233, 0.6220, 0.6237, 0.6253, 0.6298, 0.6291,
          0.6316, 0.6286, 0.6336, 0.6344, 0.6276, 0.6326, 0.6339, 0.6343, 0.6354, 0.6371]
gmf_ndcg = [0.2695, 0.3144, 0.3368, 0.3513, 0.3564, 0.3591, 0.3592, 0.3615, 0.3627, 0.3614,
            0.3645, 0.3640, 0.3661, 0.3660, 0.3626, 0.3656, 0.3685, 0.3662, 0.3661, 0.3677]

# MLP data
mlp_hr = [0.4487, 0.4755, 0.5377, 0.5694, 0.5876, 0.5896, 0.6101, 0.6124, 0.6175, 0.6220,
          0.6222, 0.6275, 0.6257, 0.6305, 0.6318, 0.6315, 0.6326, 0.6306, 0.6343, 0.6296]
mlp_ndcg = [0.2431, 0.2597, 0.2950, 0.3165, 0.3258, 0.3329, 0.3450, 0.3470, 0.3511, 0.3563,
            0.3551, 0.3598, 0.3607, 0.3648, 0.3658, 0.3633, 0.3681, 0.3666, 0.3686, 0.3662]

# NeuMF data
neumf_hr = [0.5793, 0.6121, 0.6260, 0.6247, 0.6366, 0.6445, 0.6402, 0.6464, 0.6531, 0.6546,
            0.6614, 0.6634, 0.6642, 0.6674, 0.6727, 0.6730, 0.6715, 0.6781, 0.6776, 0.6801]
neumf_ndcg = [0.3251, 0.3472, 0.3596, 0.3614, 0.3693, 0.3734, 0.3745, 0.3787, 0.3813, 0.3866,
              0.3886, 0.3903, 0.3902, 0.3947, 0.3953, 0.3987, 0.3985, 0.4020, 0.4021, 0.4033]

# Plotting HR
plt.figure(figsize=(15, 6))

# Subplot for HR
plt.subplot(1, 2, 1)
plt.plot(epochs, mlp_hr, label='MLP', linestyle='-', marker='o', linewidth=2, color='blue')
plt.plot(epochs, gmf_hr, label='GMF', linestyle='--', marker='s', linewidth=2, color='green')
plt.plot(epochs, neumf_hr, label='NeuMF', linestyle='-.', marker='^', linewidth=2, color='red')
plt.xticks(epochs)
plt.xlabel('Epoch')
plt.ylabel('HR')
plt.title('Hit Rate (HR) over Epochs')
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

# Subplot for NDCG
plt.subplot(1, 2, 2)
plt.plot(epochs, mlp_ndcg, label='MLP', linestyle='-', marker='o', linewidth=2, color='blue')
plt.plot(epochs, gmf_ndcg, label='GMF', linestyle='--', marker='s', linewidth=2, color='green')
plt.plot(epochs, neumf_ndcg, label='NeuMF', linestyle='-.', marker='^', linewidth=2, color='red')
plt.xticks(epochs)
plt.xlabel('Epoch')
plt.ylabel('NDCG')
plt.title('NDCG over Epochs')
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data for each model
epochs = list(range(20))

# MLP_2 data
mlp2_hr = [0.4508, 0.4498, 0.4765, 0.4891, 0.5015, 0.5121, 0.5245, 0.5353, 0.5477, 0.5545, 0.5591, 0.5611, 0.5616, 0.5608, 0.5661, 0.5724, 0.5719, 0.5704, 0.5765, 0.5793]
mlp2_ndcg = [0.2493, 0.2463, 0.2614, 0.2682, 0.2746, 0.2810, 0.2901, 0.2959, 0.3043, 0.3106, 0.3108, 0.3147, 0.3144, 0.3154, 0.3172, 0.3192, 0.3205, 0.3195, 0.3245, 0.3269]

# MLP_3 data
mlp3_hr = [0.4522, 0.4619, 0.4955, 0.5242, 0.5442, 0.5609, 0.5652, 0.5707, 0.5828, 0.5879, 0.5929, 0.5919, 0.5930, 0.5993, 0.6015, 0.6068, 0.6132, 0.6131, 0.6139, 0.6169]
mlp3_ndcg = [0.2467, 0.2553, 0.2729, 0.2875, 0.3011, 0.3116, 0.3179, 0.3193, 0.3275, 0.3299, 0.3324, 0.3325, 0.3358, 0.3374, 0.3402, 0.3423, 0.3460, 0.3453, 0.3461, 0.3486]

# MLP_4 data
mlp4_hr = [0.4505, 0.4818, 0.5070, 0.5440, 0.5654, 0.5818, 0.5871, 0.5892, 0.5974, 0.6050, 0.6096, 0.6104, 0.6114, 0.6123, 0.6166, 0.6177, 0.6209, 0.6202, 0.6262, 0.6235]
mlp4_ndcg = [0.2456, 0.2626, 0.2757, 0.3035, 0.3144, 0.3244, 0.3290, 0.3314, 0.3357, 0.3410, 0.3461, 0.3455, 0.3518, 0.3535, 0.3565, 0.3598, 0.3609, 0.3605, 0.3639, 0.3635]

# MLP_5 data
mlp5_hr = [0.4487, 0.4755, 0.5377, 0.5694, 0.5876, 0.5896, 0.6101, 0.6124, 0.6175, 0.6220, 0.6222, 0.6275, 0.6257, 0.6305, 0.6318, 0.6315, 0.6326, 0.6306, 0.6343, 0.6296]
mlp5_ndcg = [0.2431, 0.2597, 0.2950, 0.3165, 0.3258, 0.3329, 0.3450, 0.3470, 0.3511, 0.3563, 0.3551, 0.3598, 0.3607, 0.3648, 0.3658, 0.3633, 0.3681, 0.3666, 0.3686, 0.3662]

# Create a DataFrame for the table
final_results = {
    'Model': ['MLP_2', 'MLP_3', 'MLP_4', 'MLP_5'],
    'Best HR': [max(mlp2_hr), max(mlp3_hr), max(mlp4_hr), max(mlp5_hr)],
    'Best NDCG': [max(mlp2_ndcg), max(mlp3_ndcg), max(mlp4_ndcg), max(mlp5_ndcg)]
}

final_df = pd.DataFrame(final_results)
print(final_df.to_string(index=False))

# Plotting HR and NDCG
plt.figure(figsize=(15, 7))

# HR Plot
plt.subplot(1, 2, 1)
plt.plot(epochs, mlp2_hr, label='MLP_2', marker='o')
plt.plot(epochs, mlp3_hr, label='MLP_3', marker='s')
plt.plot(epochs, mlp4_hr, label='MLP_4', marker='D')
plt.plot(epochs, mlp5_hr, label='MLP_5', marker='^')
plt.xticks(epochs)
plt.xlabel('Epoch')
plt.ylabel('HR')
plt.title('Hit Rate (HR) over Epochs')
plt.legend()
plt.grid(True)

# Highlight best HR value
best_hr_epoch = epochs[mlp5_hr.index(max(mlp5_hr))]
best_hr_value = max(mlp5_hr)
plt.annotate(f'Best HR: {best_hr_value:.4f}',
             xy=(best_hr_epoch, best_hr_value),
             xytext=(best_hr_epoch, best_hr_value + 0.02),
             arrowprops=dict(facecolor='black', shrink=0.05),
             horizontalalignment='center')

# NDCG Plot
plt.subplot(1, 2, 2)
plt.plot(epochs, mlp2_ndcg, label='MLP_2', marker='o')
plt.plot(epochs, mlp3_ndcg, label='MLP_3', marker='s')
plt.plot(epochs, mlp4_ndcg, label='MLP_4', marker='D')
plt.plot(epochs, mlp5_ndcg, label='MLP_5', marker='^')
plt.xticks(epochs)
plt.xlabel('Epoch')
plt.ylabel('NDCG')
plt.title('NDCG over Epochs')
plt.legend()
plt.grid(True)

# Highlight best NDCG value
best_ndcg_epoch = epochs[mlp5_ndcg.index(max(mlp5_ndcg))]
best_ndcg_value = max(mlp5_ndcg)
plt.annotate(f'Best NDCG: {best_ndcg_value:.4f}',
             xy=(best_ndcg_epoch, best_ndcg_value),
             xytext=(best_ndcg_epoch, best_ndcg_value + 0.02),
             arrowprops=dict(facecolor='black', shrink=0.05),
             horizontalalignment='center')

plt.tight_layout()
plt.show()
# Out:
# Model  Best HR  Best NDCG
# MLP_2   0.5793     0.3269
# MLP_3   0.6169     0.3486
# MLP_4   0.6262     0.3639
# MLP_5   0.6343     0.3686

# %%
import pandas as pd

# Create a dictionary with the data
data = {
    'Model': ['MLP_2', 'MLP_3', 'MLP_4', 'MLP_5'],
    'Best HR': [0.5793,0.6169,0.6262,0.6343],
    'Best NDCG': [0.3269,0.3486,0.3639,0.3686]
}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data)
# Transpose the DataFrame
df = df.transpose()
# Set the first row as the column headers
df.columns = df.iloc[0]
# Drop the first row
df = df[1:]
# Display the DataFrame
df
# Out:
# Model       MLP_2   MLP_3   MLP_4   MLP_5
# Best HR    0.5793  0.6169  0.6262  0.6343
# Best NDCG  0.3269  0.3486  0.3639  0.3686
