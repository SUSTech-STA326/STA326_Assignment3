# %% [markdown]
# ## Results to Different Parameter

# %% [markdown]
# ### Model1:NeuMF (with pre-training)

# %%
# !python main.py --batch_size=256 --lr=0.001 --factor_num=8 --model='NeuMF-end'
# Out:
# Epoch 1/20: 100%|█████████| 19418/19418 [01:14<00:00, 259.90batch/s, loss=0.225]
# The time elapse of epoch 000 is: 00: 01: 38
# HR@10: 0.633	NDCG@10: 0.363
# Epoch 2/20: 100%|█████████| 19418/19418 [01:15<00:00, 257.40batch/s, loss=0.288]
# The time elapse of epoch 001 is: 00: 01: 39
# HR@10: 0.675	NDCG@10: 0.395
# Epoch 3/20: 100%|█████████| 19418/19418 [01:14<00:00, 261.47batch/s, loss=0.336]
# The time elapse of epoch 002 is: 00: 01: 39
# HR@10: 0.684	NDCG@10: 0.409
# Epoch 4/20: 100%|█████████| 19418/19418 [01:13<00:00, 262.67batch/s, loss=0.255]
# The time elapse of epoch 003 is: 00: 01: 37
# HR@10: 0.693	NDCG@10: 0.417
# Epoch 5/20: 100%|█████████| 19418/19418 [01:14<00:00, 260.42batch/s, loss=0.271]
# The time elapse of epoch 004 is: 00: 01: 38
# HR@10: 0.692	NDCG@10: 0.417
# Epoch 6/20: 100%|██████████| 19418/19418 [01:12<00:00, 266.27batch/s, loss=0.22]
# The time elapse of epoch 005 is: 00: 01: 38
# HR@10: 0.688	NDCG@10: 0.417
# ...

# %% [markdown]
# ### Model2: NeuMF (without pre-training)

# %%
# !python main.py --batch_size=256 --lr=0.001 --factor_num=8
# Out:
# Epoch 1/20: 100%|█████████| 19418/19418 [01:46<00:00, 182.34batch/s, loss=0.235]
# The time elapse of epoch 000 is: 00: 02: 20
# HR@10: 0.674	NDCG@10: 0.396
# Epoch 2/20: 100%|█████████| 19418/19418 [01:42<00:00, 188.76batch/s, loss=0.253]
# The time elapse of epoch 001 is: 00: 02: 17
# HR@10: 0.671	NDCG@10: 0.395
# Epoch 3/20: 100%|█████████| 19418/19418 [01:40<00:00, 193.76batch/s, loss=0.265]
# The time elapse of epoch 002 is: 00: 02: 13
# HR@10: 0.671	NDCG@10: 0.395
# Epoch 4/20: 100%|█████████| 19418/19418 [01:38<00:00, 197.51batch/s, loss=0.289]
# The time elapse of epoch 003 is: 00: 02: 08
# HR@10: 0.671	NDCG@10: 0.395
# Epoch 5/20: 100%|█████████| 19418/19418 [01:41<00:00, 191.42batch/s, loss=0.254]
# The time elapse of epoch 004 is: 00: 02: 11
# HR@10: 0.672	NDCG@10: 0.396
# Epoch 6/20: 100%|█████████| 19418/19418 [01:40<00:00, 193.62batch/s, loss=0.221]
# The time elapse of epoch 005 is: 00: 02: 11
# HR@10: 0.672	NDCG@10: 0.395
# ...

# %% [markdown]
# ### Model3: MLP

# %%
# !python main.py --batch_size=256 --lr=0.001 --factor_num=8 --model='MLP' --num_layers=1
# Out:
# Epoch 1/20: 100%|█████████| 19418/19418 [01:00<00:00, 323.18batch/s, loss=0.379]
# The time elapse of epoch 000 is: 00: 01: 22
# HR@10: 0.504	NDCG@10: 0.279
# Epoch 2/20: 100%|█████████| 19418/19418 [00:58<00:00, 330.52batch/s, loss=0.237]
# The time elapse of epoch 001 is: 00: 01: 22
# HR@10: 0.558	NDCG@10: 0.309
# Epoch 3/20: 100%|█████████| 19418/19418 [00:58<00:00, 329.81batch/s, loss=0.248]
# The time elapse of epoch 002 is: 00: 01: 22
# HR@10: 0.594	NDCG@10: 0.338
# Epoch 4/20: 100%|█████████| 19418/19418 [00:59<00:00, 328.07batch/s, loss=0.302]
# The time elapse of epoch 003 is: 00: 01: 21
# HR@10: 0.622	NDCG@10: 0.356
# Epoch 5/20: 100%|█████████| 19418/19418 [00:59<00:00, 327.07batch/s, loss=0.278]
# The time elapse of epoch 004 is: 00: 01: 23
# HR@10: 0.633	NDCG@10: 0.364
# Epoch 6/20: 100%|█████████| 19418/19418 [00:58<00:00, 329.87batch/s, loss=0.225]
# The time elapse of epoch 005 is: 00: 01: 22
# HR@10: 0.641	NDCG@10: 0.368
# ...

# %%
# !python main.py --batch_size=256 --lr=0.001 --factor_num=8 --model='MLP' --num_layers=2
# Out:
# Epoch 1/20: 100%|█████████| 19418/19418 [01:03<00:00, 304.77batch/s, loss=0.235]
# The time elapse of epoch 000 is: 00: 01: 26
# HR@10: 0.543	NDCG@10: 0.303
# Epoch 2/20: 100%|█████████| 19418/19418 [01:04<00:00, 301.08batch/s, loss=0.295]
# The time elapse of epoch 001 is: 00: 01: 27
# HR@10: 0.608	NDCG@10: 0.344
# Epoch 3/20: 100%|█████████| 19418/19418 [01:04<00:00, 302.24batch/s, loss=0.306]
# The time elapse of epoch 002 is: 00: 01: 27
# HR@10: 0.635	NDCG@10: 0.366
# Epoch 4/20: 100%|█████████| 19418/19418 [01:02<00:00, 308.86batch/s, loss=0.169]
# The time elapse of epoch 003 is: 00: 01: 25
# HR@10: 0.654	NDCG@10: 0.382
# Epoch 5/20: 100%|█████████| 19418/19418 [01:03<00:00, 305.92batch/s, loss=0.259]
# The time elapse of epoch 004 is: 00: 01: 26
# HR@10: 0.669	NDCG@10: 0.391
# Epoch 6/20: 100%|█████████| 19418/19418 [01:03<00:00, 306.01batch/s, loss=0.337]
# The time elapse of epoch 005 is: 00: 01: 27
# HR@10: 0.674	NDCG@10: 0.395
# ...

# %%
# !python main.py --batch_size=256 --lr=0.001 --factor_num=8 --model='MLP' --num_layers=3
# Out:
# Epoch 1/20: 100%|█████████| 19418/19418 [01:08<00:00, 281.87batch/s, loss=0.367]
# The time elapse of epoch 000 is: 00: 01: 32
# HR@10: 0.555	NDCG@10: 0.311
# Epoch 2/20: 100%|██████████| 19418/19418 [01:08<00:00, 282.06batch/s, loss=0.25]
# The time elapse of epoch 001 is: 00: 01: 32
# HR@10: 0.615	NDCG@10: 0.349
# Epoch 3/20: 100%|█████████| 19418/19418 [01:08<00:00, 281.46batch/s, loss=0.347]
# The time elapse of epoch 002 is: 00: 01: 34
# HR@10: 0.640	NDCG@10: 0.372
# Epoch 4/20: 100%|█████████| 19418/19418 [01:10<00:00, 277.17batch/s, loss=0.167]
# The time elapse of epoch 003 is: 00: 01: 33
# HR@10: 0.656	NDCG@10: 0.384
# Epoch 5/20: 100%|█████████| 19418/19418 [01:09<00:00, 280.43batch/s, loss=0.262]
# The time elapse of epoch 004 is: 00: 01: 33
# HR@10: 0.665	NDCG@10: 0.392
# Epoch 6/20: 100%|█████████| 19418/19418 [01:08<00:00, 281.46batch/s, loss=0.245]
# The time elapse of epoch 005 is: 00: 01: 33
# HR@10: 0.686	NDCG@10: 0.405
# ...

# %%
# !python main.py --batch_size=256 --lr=0.001 --factor_num=8 --model='MLP' --num_layers=4
# Out:
# Epoch 1/20: 100%|█████████| 19418/19418 [01:16<00:00, 252.31batch/s, loss=0.271]
# The time elapse of epoch 000 is: 00: 01: 40
# HR@10: 0.553	NDCG@10: 0.301
# Epoch 2/20: 100%|█████████| 19418/19418 [01:17<00:00, 249.25batch/s, loss=0.286]
# The time elapse of epoch 001 is: 00: 01: 41
# HR@10: 0.621	NDCG@10: 0.353
# Epoch 3/20: 100%|█████████| 19418/19418 [01:17<00:00, 250.09batch/s, loss=0.227]
# The time elapse of epoch 002 is: 00: 01: 41
# HR@10: 0.645	NDCG@10: 0.374
# Epoch 4/20: 100%|█████████| 19418/19418 [01:15<00:00, 255.74batch/s, loss=0.232]
# The time elapse of epoch 003 is: 00: 01: 38
# HR@10: 0.673	NDCG@10: 0.394
# Epoch 5/20: 100%|█████████| 19418/19418 [01:15<00:00, 255.78batch/s, loss=0.256]
# The time elapse of epoch 004 is: 00: 01: 40
# HR@10: 0.671	NDCG@10: 0.398
# Epoch 6/20: 100%|██████████| 19418/19418 [01:17<00:00, 250.59batch/s, loss=0.18]
# The time elapse of epoch 005 is: 00: 01: 42
# HR@10: 0.682	NDCG@10: 0.404
# ...

# %% [markdown]
# ### Model4: GMF

# %%
# !python main.py --batch_size=256 --lr=0.001 --factor_num=8 --model='GMF'
# Out:
# Epoch 1/20: 100%|█████████| 19418/19418 [00:55<00:00, 349.21batch/s, loss=0.352]
# The time elapse of epoch 000 is: 00: 01: 18
# HR@10: 0.562	NDCG@10: 0.320
# Epoch 2/20: 100%|█████████| 19418/19418 [00:54<00:00, 353.64batch/s, loss=0.229]
# The time elapse of epoch 001 is: 00: 01: 18
# HR@10: 0.630	NDCG@10: 0.358
# Epoch 3/20: 100%|█████████| 19418/19418 [00:55<00:00, 349.29batch/s, loss=0.203]
# The time elapse of epoch 002 is: 00: 01: 19
# HR@10: 0.651	NDCG@10: 0.378
# Epoch 4/20: 100%|█████████| 19418/19418 [00:55<00:00, 352.77batch/s, loss=0.216]
# The time elapse of epoch 003 is: 00: 01: 17
# HR@10: 0.669	NDCG@10: 0.393
# Epoch 5/20: 100%|█████████| 19418/19418 [00:55<00:00, 351.10batch/s, loss=0.313]
# The time elapse of epoch 004 is: 00: 01: 18
# HR@10: 0.676	NDCG@10: 0.400
# Epoch 6/20: 100%|█████████| 19418/19418 [00:55<00:00, 350.81batch/s, loss=0.222]
# The time elapse of epoch 005 is: 00: 01: 19
# HR@10: 0.682	NDCG@10: 0.407
# ...
