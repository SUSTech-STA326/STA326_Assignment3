# %%
import matplotlib.pyplot as plt

# Data for each model
epochs = list(range(20))

# MLP_3 data
mlp3_hr = [0.524, 0.578, 0.603, 0.621, 0.635, 0.639, 0.655, 0.658, 0.661, 0.657, 
           0.663, 0.662, 0.661, 0.665, 0.663, 0.672, 0.664, 0.668, 0.666, 0.664]
mlp3_ndcg = [0.290, 0.326, 0.345, 0.355, 0.368, 0.372, 0.382, 0.381, 0.388, 0.387, 
             0.392, 0.390, 0.390, 0.391, 0.393, 0.395, 0.397, 0.395, 0.393, 0.394]

# GMF data
gmf_hr = [0.538, 0.606, 0.621, 0.638, 0.644, 0.656, 0.662, 0.665, 0.662, 0.671, 
          0.666, 0.674, 0.669, 0.665, 0.666, 0.675, 0.674, 0.676, 0.671, 0.676]
gmf_ndcg = [0.301, 0.343, 0.358, 0.369, 0.374, 0.384, 0.390, 0.391, 0.389, 0.396, 
            0.392, 0.397, 0.397, 0.394, 0.395, 0.400, 0.399, 0.400, 0.400, 0.402]

# NeuMF-pre data
neumf_pre_hr = [0.527, 0.591, 0.619, 0.628, 0.646, 0.650, 0.659, 0.657, 0.674, 0.668, 
                0.666, 0.665, 0.671, 0.667, 0.669, 0.667, 0.670, 0.665, 0.668, 0.667]
neumf_pre_ndcg = [0.295, 0.335, 0.355, 0.365, 0.380, 0.383, 0.385, 0.385, 0.392, 0.391, 
                  0.392, 0.392, 0.394, 0.393, 0.395, 0.397, 0.398, 0.395, 0.396, 0.396]

# NeuMF-end data
neumf_end_hr = [0.523, 0.583, 0.620, 0.625, 0.639, 0.642, 0.645, 0.650, 0.651, 0.657, 
                0.659, 0.665, 0.666, 0.668, 0.661, 0.668, 0.667, 0.663, 0.667, 0.669]
neumf_end_ndcg = [0.295, 0.328, 0.352, 0.365, 0.375, 0.378, 0.379, 0.383, 0.387, 0.388, 
                  0.390, 0.392, 0.395, 0.394, 0.392, 0.393, 0.394, 0.394, 0.396, 0.396]

# Plotting HR
plt.figure(figsize=(13, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, mlp3_hr, label='MLP_3',linestyle='--',marker='*',linewidth=2)
plt.plot(epochs, gmf_hr, label='GMF',linestyle='-.',marker='o',linewidth=2)
plt.plot(epochs, neumf_pre_hr, label='NeuMF-pre',linestyle='-',marker='^',linewidth=2)
plt.plot(epochs, neumf_end_hr, label='NeuMF-end',linestyle=':',marker='+',linewidth=2)
plt.xticks(epochs)
plt.xlabel('Epoch')
plt.ylabel('HR')
plt.title('Hit Rate (HR) over Epochs')
plt.legend()
plt.grid(True)

# Plotting NDCG
plt.subplot(1, 2, 2)
plt.plot(epochs, mlp3_ndcg, label='MLP_3',linestyle='--',marker='*',linewidth=2)
plt.plot(epochs, gmf_ndcg, label='GMF',linestyle='-.',marker='o',linewidth=2)
plt.plot(epochs, neumf_pre_ndcg, label='NeuMF-pre',linestyle='-',marker='^',linewidth=2)
plt.plot(epochs, neumf_end_ndcg, label='NeuMF-end',linestyle=':',marker='+',linewidth=2)
plt.xticks(epochs)
plt.xlabel('Epoch')
plt.ylabel('NDCG')
plt.title('NDCG over Epochs')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# 定义各个模型的数据
epochs = list(range(20))

mlp3_hr = [0.520, 0.581, 0.609, 0.625, 0.640, 0.642, 0.653, 0.655, 0.658, 0.661, 0.661, 0.668, 0.667, 0.663, 0.661, 0.668, 0.664, 0.662, 0.665, 0.667]
mlp3_ndcg = [0.290, 0.327, 0.346, 0.359, 0.370, 0.374, 0.380, 0.385, 0.390, 0.390, 0.389, 0.394, 0.390, 0.391, 0.387, 0.391, 0.391, 0.393, 0.390, 0.393]

gmf_hr = [0.511, 0.570, 0.597, 0.619, 0.620, 0.627, 0.631, 0.635, 0.630, 0.630, 0.629, 0.635, 0.634, 0.634, 0.637, 0.638, 0.638, 0.641, 0.637, 0.635]
gmf_ndcg = [0.283, 0.318, 0.339, 0.353, 0.357, 0.361, 0.362, 0.365, 0.365, 0.367, 0.364, 0.366, 0.366, 0.367, 0.367, 0.368, 0.368, 0.369, 0.368, 0.366]

# NeuMF-pre data
neumf_pre_hr = [0.527, 0.591, 0.619, 0.628, 0.646, 0.650, 0.659, 0.657, 0.674, 0.668, 0.666, 0.665, 0.671, 0.667, 0.669, 0.667, 0.670, 0.665, 0.668, 0.667]
neumf_pre_ndcg = [0.295, 0.335, 0.355, 0.365, 0.380, 0.383, 0.385, 0.385, 0.392, 0.391, 0.392, 0.392, 0.394, 0.393, 0.395, 0.397, 0.398, 0.395, 0.396, 0.396]

neumf_end_hr = [0.595, 0.633, 0.651, 0.665, 0.665, 0.666, 0.676, 0.671, 0.677, 0.681, 0.681, 0.681, 0.682, 0.685, 0.680, 0.685, 0.688, 0.686, 0.685, 0.686]
neumf_end_ndcg = [0.337, 0.365, 0.380, 0.387, 0.391, 0.394, 0.398, 0.397, 0.402, 0.404, 0.402, 0.404, 0.409, 0.408, 0.406, 0.409, 0.411, 0.410, 0.408, 0.411]

# Plotting HR
plt.figure(figsize=(13, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, mlp3_hr, label='MLP_3',linestyle='--',marker='*',linewidth=2)
plt.plot(epochs, gmf_hr, label='GMF',linestyle='-.',marker='o',linewidth=2)
plt.plot(epochs, neumf_pre_hr, label='NeuMF-pre',linestyle='-',marker='^',linewidth=2)
plt.plot(epochs, neumf_end_hr, label='NeuMF-end',linestyle=':',marker='+',linewidth=2)
plt.xticks(epochs)
plt.xlabel('Epoch')
plt.ylabel('HR')
plt.title('Hit Rate (HR) over Epochs')
plt.legend()
plt.grid(True)

# Plotting NDCG
plt.subplot(1, 2, 2)
plt.plot(epochs, mlp3_ndcg, label='MLP_3',linestyle='--',marker='*',linewidth=2)
plt.plot(epochs, gmf_ndcg, label='GMF',linestyle='-.',marker='o',linewidth=2)
plt.plot(epochs, neumf_pre_ndcg, label='NeuMF-pre',linestyle='-',marker='^',linewidth=2)
plt.plot(epochs, neumf_end_ndcg, label='NeuMF-end',linestyle=':',marker='+',linewidth=2)
plt.xticks(epochs)
plt.xlabel('Epoch')
plt.ylabel('NDCG')
plt.title('NDCG over Epochs')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data for each model
epochs = list(range(20))

# MLP_0 data
mlp0_hr = [0.448, 0.455, 0.452, 0.451, 0.451, 0.451, 0.450, 0.449, 0.450, 0.452,
           0.450, 0.451, 0.451, 0.453, 0.450, 0.453, 0.452, 0.445, 0.452, 0.453]
mlp0_ndcg = [0.250, 0.253, 0.251, 0.250, 0.251, 0.252, 0.251, 0.250, 0.251, 0.252,
             0.252, 0.252, 0.251, 0.252, 0.251, 0.252, 0.252, 0.251, 0.252, 0.252]

# MLP_1 data
mlp1_hr = [0.464, 0.490, 0.518, 0.548, 0.565, 0.578, 0.589, 0.586, 0.591, 0.591,
           0.594, 0.596, 0.598, 0.604, 0.603, 0.609, 0.605, 0.603, 0.606, 0.606]
mlp1_ndcg = [0.257, 0.272, 0.287, 0.305, 0.317, 0.325, 0.330, 0.328, 0.331, 0.330,
             0.332, 0.336, 0.335, 0.336, 0.336, 0.341, 0.339, 0.339, 0.340, 0.343]

# MLP_2 data
mlp2_hr = [0.516, 0.563, 0.584, 0.600, 0.609, 0.620, 0.624, 0.630, 0.629, 0.625,
           0.630, 0.638, 0.642, 0.636, 0.642, 0.643, 0.638, 0.640, 0.647, 0.646]
mlp2_ndcg = [0.285, 0.314, 0.330, 0.338, 0.344, 0.354, 0.359, 0.359, 0.361, 0.360,
             0.363, 0.365, 0.370, 0.368, 0.371, 0.373, 0.371, 0.372, 0.372, 0.377]

# MLP_3 data
mlp3_hr = [0.524, 0.578, 0.603, 0.621, 0.635, 0.639, 0.655, 0.658, 0.661, 0.657,
           0.663, 0.662, 0.661, 0.665, 0.663, 0.672, 0.664, 0.668, 0.666, 0.664]
mlp3_ndcg = [0.290, 0.326, 0.345, 0.355, 0.368, 0.372, 0.382, 0.381, 0.388, 0.387,
             0.392, 0.390, 0.390, 0.391, 0.393, 0.395, 0.397, 0.395, 0.393, 0.394]

# MLP_4 data
mlp4_hr = [0.537, 0.597, 0.621, 0.644, 0.662, 0.663, 0.673, 0.673, 0.667, 0.672,
           0.674, 0.677, 0.676, 0.666, 0.673, 0.675, 0.681, 0.679, 0.681, 0.673]
mlp4_ndcg = [0.300, 0.336, 0.358, 0.371, 0.385, 0.389, 0.398, 0.398, 0.397, 0.397,
             0.403, 0.402, 0.402, 0.398, 0.403, 0.404, 0.406, 0.406, 0.407, 0.404]

# Plotting HR
plt.figure(figsize=(13, 5))

# HR Plot
plt.subplot(1, 2, 1)
plt.plot(epochs, mlp0_hr, label='MLP_0')
plt.plot(epochs, mlp1_hr, label='MLP_1')
plt.plot(epochs, mlp2_hr, label='MLP_2')
plt.plot(epochs, mlp3_hr, label='MLP_3')
plt.plot(epochs, mlp4_hr, label='MLP_4')
plt.xticks(epochs)
plt.xlabel('Epoch')
plt.ylabel('HR')
plt.title('Hit Rate (HR) over Epochs')
plt.legend()
plt.grid(True)

# NDCG Plot
plt.subplot(1, 2, 2)
plt.plot(epochs, mlp0_ndcg, label='MLP_0')
plt.plot(epochs, mlp1_ndcg, label='MLP_1')
plt.plot(epochs, mlp2_ndcg, label='MLP_2')
plt.plot(epochs, mlp3_ndcg, label='MLP_3')
plt.plot(epochs, mlp4_ndcg, label='MLP_4')
plt.xticks(epochs)
plt.xlabel('Epoch')
plt.ylabel('NDCG')
plt.title('NDCG over Epochs')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# Create a DataFrame for the table
data = {
    'Epoch': epochs,
    'MLP_0_HR': mlp0_hr,
    'MLP_0_NDCG': mlp0_ndcg,
    'MLP_1_HR': mlp1_hr,
    'MLP_1_NDCG': mlp1_ndcg,
    'MLP_2_HR': mlp2_hr,
    'MLP_2_NDCG': mlp2_ndcg,
    'MLP_3_HR': mlp3_hr,
    'MLP_3_NDCG': mlp3_ndcg,
    'MLP_4_HR': mlp4_hr,
    'MLP_4_NDCG': mlp4_ndcg
}

df = pd.DataFrame(data)
df
# Out:
#     Epoch  MLP_0_HR  MLP_0_NDCG  MLP_1_HR  MLP_1_NDCG  MLP_2_HR  MLP_2_NDCG  \
# 0       0     0.448       0.250     0.464       0.257     0.516       0.285
# 1       1     0.455       0.253     0.490       0.272     0.563       0.314
# 2       2     0.452       0.251     0.518       0.287     0.584       0.330
# 3       3     0.451       0.250     0.548       0.305     0.600       0.338
# 4       4     0.451       0.251     0.565       0.317     0.609       0.344
# 5       5     0.451       0.252     0.578       0.325     0.620       0.354
# 6       6     0.450       0.251     0.589       0.330     0.624       0.359
# 7       7     0.449       0.250     0.586       0.328     0.630       0.359
# 8       8     0.450       0.251     0.591       0.331     0.629       0.361
# 9       9     0.452       0.252     0.591       0.330     0.625       0.360
# 10     10     0.450       0.252     0.594       0.332     0.630       0.363
# ...

# %%
# Create a 2x5 table of the final results
final_results = {
    'Model': ['MLP_0', 'MLP_1', 'MLP_2', 'MLP_3', 'MLP_4'],
    'Best HR': [0.455, 0.609, 0.647, 0.672, 0.681],
    'Best NDCG': [0.253, 0.341, 0.372, 0.395, 0.406]
}

final_df = pd.DataFrame(final_results)
print(final_df.to_string(index=False))
# Out:
# Model  Best HR  Best NDCG
# MLP_0    0.455      0.253
# MLP_1    0.609      0.341
# MLP_2    0.647      0.372
# MLP_3    0.672      0.395
# MLP_4    0.681      0.406

# %%
import pandas as pd

# Create a dictionary with the data
data = {
    'Model': ['MLP_0', 'MLP_1', 'MLP_2', 'MLP_3', 'MLP_4'],
    'Best HR': [0.455, 0.609, 0.647, 0.672, 0.681],
    'Best NDCG': [0.253, 0.341, 0.372, 0.395, 0.406]
}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data)
# Transpose the DataFrame
df = df.transpose()
# Set the first row as the column headers
df.columns = df.iloc[0]
# Drop the first row
df = df[1:]
# Display the DataFrame
df
# Out:
# Model      MLP_0  MLP_1  MLP_2  MLP_3  MLP_4
# Best HR    0.455  0.609  0.647  0.672  0.681
# Best NDCG  0.253  0.341  0.372  0.395  0.406
